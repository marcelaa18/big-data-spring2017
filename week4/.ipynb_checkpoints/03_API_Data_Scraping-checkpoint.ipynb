# %% [markdown]
# Big Data And Society: Lab 3
# =====

# %% [markdown]
# # APIs and Data Scraping: Getting Twitter Data

# %% [markdown]
# ### 0. Set up a Twitter Application
#
# This week we are going to scrape data from the Twitter API and make some plots! We are going to use the Twitter REST API, which lets us query and retreive samples of Tweets. To do this, you need API keys that are associated with your account. Your API keys are secret and unique to you and only you, and they gives you access to Twitter data through the API.
#
# There are a couple of ways to get Twitter data, the REST API is just one of them. The others are to set up a Streamer (which streams real time tweets), or to access the Firehose (this means everything!). Read [this article](https://brightplanet.com/2013/06/twitter-firehose-vs-twitter-api-whats-the-difference-and-why-should-you-care/) for a nice comparison between the methods.
#
# The Twitter REST API is best place to start and what we will use in class. Follow the following steps to get your keys.
#
# * Create a twitter account if you do not already have one.
# * Go to [https://apps.twitter.com/](https://apps.twitter.com/) and log in with your twitter credentials.
# * Click **"Create New App"** in the upper right corner
# * Fill out the form, give it a name like **data_getter_yourname** and a description, agree to the terms, and click **"Create your Twitter application"** *Note: The form will ask for a website. You can put the github.io page you made as the URL. **It is OK for your callback URL to be blank.***
# * In the next page, click on **Keys and Access Tokens** tab, and copy your "Consumer Key (API Key)" and "Consumer Key (API Secret)".
#
# We need a Python file that will contain the **Twitter** keys. It is never a good idea to host these keys on a public website like **github**, so one way to keep them private is importing the keys as a variable from a separate, untracked file. Open your text editor, and in the materials for the week, *PASTE* these keys into the **twitter-keys.py** file and save the file. Using this method, we can then import the keys and use them on a repeated basis, and we can choose not to put this file on Github. **Make sure they are saved as strings!**
#
# **!!IMPORTANT NOTE!! NEVER SAVE YOUR TWITTER_KEY.PY FILE TO GITHUB. IF YOU DO, PEOPLE CAN SEE YOUR KEYS AND USE THEM. KEEP THESE ON YOUR MACHINE.**

# %% [markdown]
# ### 1. Importing the Libraries and Twitter Keys
#
# We will be using **Twython**, a Python library that provides wrappers around Twitter's API. To install **Twython** on a terminal or the command line, run the following command:
#
# ```
# pip install twython
# ```
#
# We also need to import the keys we just got from Twitter to be accessible to our code. View the contents of **twitter_key.py** to see your keys. These should both be strings.
#
# ```
# # In the file you should define two variables:
# api_key = "your twitter key"
# api_secret = "your twitter secret"
# ```
#
# Import the libraries:

# %%
# Import libraries
import json
import time
import threading
from datetime import datetime
from twython import Twython

# Imports the keys from the python file
from twitter_key import api_key, api_secret
api_key
# Out:
# 'kmOvaZ7XgKnslVyVoZ34D3jWt'

# %% [markdown]
# ### 2. Set Up Twython, Get an OAuth2 Token, and Create your Twython Object
#
# In this next step, assign the keys to variables and set up our instance of Twython to work with your account.
#
# Doing this requires our authentication with Twitter using our keys. Twitter uses something called [OAuth](https://dev.twitter.com/oauth) for API authentication. There are two types of OAuth authentication. OAuth1 provides user authentication to the API, and is required to post tweets and issue requests on behalf of users. OAuth 2 is [application-only authentication](https://dev.twitter.com/oauth/application-only), and has higher rate limits but doesn't allow you to post on users behalf. Because we can get more tweets using it, we are going to use OAuth2.
#
# **OAuth 2 requires a Third Access token you must request using the API. This next step will set everything up for us.**
#
# In the last part of this, we create a **Twython** object and call it **my_twython**; this object simplifies the access to the [Twitter API](https://dev.twitter.com/overview/documentation), and provides methods for accessing the API’s endpoints. The first function fetches tweets with a given query at a given lat-long. We will be using the search parameters to hit the APIs endpoint. We need to provide the lat/lon of the centroid of the area we want to query, maximum number of tweets to return, and area within the centroid to search for, among others.

# %%
# Assigns the keys to the variables
APP_KEY = api_key
APP_SECRET = api_secret

# Create a Twython object called Twitter
# Set this up using your Twitter Keys
# Say we are going to use OAuth 2
twython_setup = Twython(APP_KEY, APP_SECRET, oauth_version=2)

# Get an OAuth2 access token, save as variable so we can launch our 
OAUTH2_ACCESS_TOKEN = twython_setup.obtain_access_token()

# Create a Twython Object we will use for our access to the API
my_twython = Twython(APP_KEY, access_token=OAUTH2_ACCESS_TOKEN)

# %% [markdown]
# For reference, the Twython documentation and all available commands can be found here. [https://twython.readthedocs.io/en/latest/usage/starting_out.html](https://twython.readthedocs.io/en/latest/usage/starting_out.html)

# %% [markdown]
# ### 3. Query the Twitter API to get Tweets at a Location
#
# Next, let's do a search and get some tweets! Specifically, set up a function that will use the **search** API. Read more about the **search** API [here](https://dev.twitter.com/rest/reference/get/search/tweets).
#
# The **Search API** can take many parameters for querying tweets. Twitter has a nice page of what you can use as query parameters here [https://dev.twitter.com/rest/public/search](https://dev.twitter.com/rest/public/search).
#
# The Twitter API has rate limits that limit how quickly you can download data. This is to try to lighten the load on their servers. We are using the Search API with **OAuth2 (Application) Access** - which limits us to **450 in 15 minutes** Read about the [Rate Limits](https://dev.twitter.com/rest/public/rate-limiting) here. This means, in our following steps, always follow the guideline that you will not be able to get more than 450 tweets in 15 minutes, or Twitter might lock your access.

# %%
# Input the search term you want to search on
search_term='MIT' # SET A SEARCH TERM LIKE 'TRUMP'
# CAN LEAVE search_term BLANK IF YOU WANT ALL TWEETS NEAR A SPECIFIC LOCATION
# Setup a Lat Lon
latlong=[40.261455,-76.882553] # Downtown Harrisburg, PA - Capital of Pennsylvania
# Setup a search distance
distance='25mi'
# Set result type (can be 'recent', 'popular', or 'mixed')
type_of_result='recent'
# Set number of results (up to 100, remember you can only get 450 in 15 minutes)
number_of_tweets=15


# Fetches tweets with a given query at a given lat-long.
def get_tweets_by_location( latlong=None ):
    # Uses the search function to hit the APIs endpoints and look for recent tweets within the area
    results = my_twython.search(q=search_term, geocode=str(latlong[0])+','+str(latlong[1])+','+ distance, result_type=type_of_result, count=number_of_tweets)
    # Returns only the statuses from the resulting JSON
    return results['statuses']

# test run our function
get_tweets_by_location(latlong)
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 13:59:44 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 41506199,
#      'id_str': '41506199',
#      'indices': [4, 16],
#      'name': 'Upstatement',
#      'screen_name': 'upstatement'}]},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 836939011939831810,
#   'id_str': '836939011939831810',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'text': 'Hey @upstatement I love the work you did for the MIT Technology Review!',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri May 18 13:55:49 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Creative Director at @AspireUniversal. Organizer: Carlisle WordPress Meetup. @AIGA Ambassador. Tweets are my own.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'azraelgroup.com',
#        'expanded_url': 'http://azraelgroup.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/x8CbeXBCY0'}]}},
#    'favourites_count': 19429,
#    'follow_request_sent': None,
#    'followers_count': 894,
#    'following': None,
#    'friends_count': 901,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 583831432,
#    'id_str': '583831432',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 140,
#    'location': 'Carlisle, PA',
#    'name': 'Tim McKenna',
#    'notifications': None,
#    'profile_background_color': '022330',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/685539114612068352/MOQZT0K8.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/685539114612068352/MOQZT0K8.jpg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/583831432/1476451684',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/685539468057665536/UEJAO1rG_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/685539468057665536/UEJAO1rG_normal.jpg',
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'C0DFEC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'AzraelGroup',
#    'statuses_count': 15110,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/x8CbeXBCY0',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Feb 25 18:24:37 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 38445080,
#      'id_str': '38445080',
#      'indices': [0, 12],
#      'name': 'typeOneg',
#      'screen_name': 'typeOneg_at'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 835556119506477056,
#   'id_str': '835556119506477056',
#   'in_reply_to_screen_name': 'typeOneg_at',
#   'in_reply_to_status_id': 835123066405531649,
#   'in_reply_to_status_id_str': '835123066405531649',
#   'in_reply_to_user_id': 38445080,
#   'in_reply_to_user_id_str': '38445080',
#   'is_quote_status': False,
#   'lang': 'de',
#   'metadata': {'iso_language_code': 'de', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@typeOneg_at danke, dass du dieses Erlebnis mit uns geteilt hast!',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Feb 18 18:59:12 +0000 2017',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'come here my fellows, right under the gallows and listen what i have to say.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 26,
#    'follow_request_sent': None,
#    'followers_count': 7,
#    'following': None,
#    'friends_count': 9,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 833028106264915968,
#    'id_str': '833028106264915968',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'de',
#    'listed_count': 0,
#    'location': 'Jonestown',
#    'name': 'ユーニクス',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/833028106264915968/1487445513',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/833032807970701312/bf2wNTS5_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/833032807970701312/bf2wNTS5_normal.jpg',
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'dyadaddo',
#    'statuses_count': 150,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Feb 24 14:08:08 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 48972679,
#      'id_str': '48972679',
#      'indices': [0, 8],
#      'name': 'Markus Popp',
#      'screen_name': 'mpopp75'},
#     {'id': 1917663662,
#      'id_str': '1917663662',
#      'indices': [9, 18],
#      'name': 'guenschl',
#      'screen_name': 'guenschl'},
#     {'id': 854535318,
#      'id_str': '854535318',
#      'indices': [19, 28],
#      'name': 'Julia Herr',
#      'screen_name': 'frauherr'}]},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 835129186964680706,
#   'id_str': '835129186964680706',
#   'in_reply_to_screen_name': 'mpopp75',
#   'in_reply_to_status_id': 835122100562194432,
#   'in_reply_to_status_id_str': '835122100562194432',
#   'in_reply_to_user_id': 48972679,
#   'in_reply_to_user_id_str': '48972679',
#   'is_quote_status': False,
#   'lang': 'de',
#   'metadata': {'iso_language_code': 'de', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@mpopp75 @guenschl @frauherr naja, hobbydies, hobbydas, irgendwas mit internet ... low energy detektiert.',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Feb 18 18:59:12 +0000 2017',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'come here my fellows, right under the gallows and listen what i have to say.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 26,
#    'follow_request_sent': None,
#    'followers_count': 7,
#    'following': None,
#    'friends_count': 9,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 833028106264915968,
#    'id_str': '833028106264915968',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'de',
#    'listed_count': 0,
#    'location': 'Jonestown',
#    'name': 'ユーニクス',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/833028106264915968/1487445513',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/833032807970701312/bf2wNTS5_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/833032807970701312/bf2wNTS5_normal.jpg',
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'dyadaddo',
#    'statuses_count': 150,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Feb 24 02:28:58 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/6dwWfmWjW9',
#      'expanded_url': 'https://twitter.com/divbyzero/status/834775231575109632/photo/1',
#      'id': 834775071084466176,
#      'id_str': '834775071084466176',
#      'indices': [97, 120],
#      'media_url': 'http://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'sizes': {'large': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'medium': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'small': {'h': 114, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 834775231575109632,
#      'source_status_id_str': '834775231575109632',
#      'source_user_id': 15810838,
#      'source_user_id_str': '15810838',
#      'type': 'photo',
#      'url': 'https://t.co/6dwWfmWjW9'}],
#    'symbols': [],
#    'urls': [{'display_url': 'courses.csail.mit.edu/6.857/2012/fil…',
#      'expanded_url': 'http://courses.csail.mit.edu/6.857/2012/files/H03-Cryptosystem-proposed-by-Nash.pdf',
#      'indices': [73, 96],
#      'url': 'https://t.co/luwMfF3dxi'}],
#    'user_mentions': [{'id': 15810838,
#      'id_str': '15810838',
#      'indices': [3, 13],
#      'name': 'Dave Richeson',
#      'screen_name': 'divbyzero'},
#     {'id': 1556664198,
#      'id_str': '1556664198',
#      'indices': [16, 28],
#      'name': 'Kyle Cranmer',
#      'screen_name': 'KyleCranmer'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/6dwWfmWjW9',
#      'expanded_url': 'https://twitter.com/divbyzero/status/834775231575109632/photo/1',
#      'id': 834775071084466176,
#      'id_str': '834775071084466176',
#      'indices': [97, 120],
#      'media_url': 'http://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'sizes': {'large': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'medium': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'small': {'h': 114, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 834775231575109632,
#      'source_status_id_str': '834775231575109632',
#      'source_user_id': 15810838,
#      'source_user_id_str': '15810838',
#      'type': 'photo',
#      'url': 'https://t.co/6dwWfmWjW9'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 834953234577940480,
#   'id_str': '834953234577940480',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 4,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Feb 23 14:41:39 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/6dwWfmWjW9',
#       'expanded_url': 'https://twitter.com/divbyzero/status/834775231575109632/photo/1',
#       'id': 834775071084466176,
#       'id_str': '834775071084466176',
#       'indices': [82, 105],
#       'media_url': 'http://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#       'sizes': {'large': {'h': 174, 'resize': 'fit', 'w': 1034},
#        'medium': {'h': 174, 'resize': 'fit', 'w': 1034},
#        'small': {'h': 114, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/6dwWfmWjW9'}],
#     'symbols': [],
#     'urls': [{'display_url': 'courses.csail.mit.edu/6.857/2012/fil…',
#       'expanded_url': 'http://courses.csail.mit.edu/6.857/2012/files/H03-Cryptosystem-proposed-by-Nash.pdf',
#       'indices': [58, 81],
#       'url': 'https://t.co/luwMfF3dxi'}],
#     'user_mentions': [{'id': 1556664198,
#       'id_str': '1556664198',
#       'indices': [1, 13],
#       'name': 'Kyle Cranmer',
#       'screen_name': 'KyleCranmer'}]},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/6dwWfmWjW9',
#       'expanded_url': 'https://twitter.com/divbyzero/status/834775231575109632/photo/1',
#       'id': 834775071084466176,
#       'id_str': '834775071084466176',
#       'indices': [82, 105],
#       'media_url': 'http://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#       'sizes': {'large': {'h': 174, 'resize': 'fit', 'w': 1034},
#        'medium': {'h': 174, 'resize': 'fit', 'w': 1034},
#        'small': {'h': 114, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/6dwWfmWjW9'}]},
#    'favorite_count': 7,
#    'favorited': False,
#    'geo': None,
#    'id': 834775231575109632,
#    'id_str': '834775231575109632',
#    'in_reply_to_screen_name': 'KyleCranmer',
#    'in_reply_to_status_id': 834599132597780481,
#    'in_reply_to_status_id_str': '834599132597780481',
#    'in_reply_to_user_id': 1556664198,
#    'in_reply_to_user_id_str': '1556664198',
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 4,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': ".@KyleCranmer Here's Nash's sentence handwritten. Source: https://t.co/luwMfF3dxi https://t.co/6dwWfmWjW9",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Aug 11 17:39:51 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "Mathematics professor at Dickinson College, author of Euler's Gem (@EulersGem), and editor of Math Horizons (@MathHorizons).",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'divisbyzero.com',
#         'expanded_url': 'http://divisbyzero.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/d9Ispqjwwy'}]}},
#     'favourites_count': 1849,
#     'follow_request_sent': None,
#     'followers_count': 9234,
#     'following': None,
#     'friends_count': 800,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 15810838,
#     'id_str': '15810838',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 572,
#     'location': 'Carlisle, PA',
#     'name': 'Dave Richeson',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/753906400/c0fa61113fe955400ad00618c2318481.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/753906400/c0fa61113fe955400ad00618c2318481.jpeg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15810838/1398196610',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3057810921/6d52467c49383aa4f9d27ceca931e918_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3057810921/6d52467c49383aa4f9d27ceca931e918_normal.jpeg',
#     'profile_link_color': '8C8C8C',
#     'profile_sidebar_border_color': '181A1E',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '2FC2EF',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'divbyzero',
#     'statuses_count': 10311,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/d9Ispqjwwy',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "RT @divbyzero: .@KyleCranmer Here's Nash's sentence handwritten. Source: https://t.co/luwMfF3dxi https://t.co/6dwWfmWjW9",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Jan 07 14:56:30 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': "【利用目的】資料収集 #Education, #Ethics, #Philosophy, #Science, #Freud, #Lacan, : Reference Materials, Library : Ryusei's Mum, wife, ひとり息子 大学４年生(採用内定 Toyota Motor Corp.)",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 206187,
#    'follow_request_sent': None,
#    'followers_count': 3314,
#    'following': None,
#    'friends_count': 2502,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 235173460,
#    'id_str': '235173460',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ja',
#    'listed_count': 54,
#    'location': 'Japan  Kagoshima city',
#    'name': 'Erika.B  "Atsu-hime"',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/235173460/1476406881',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000819670923/899d6a566ff3cd4b0d499b4486274243_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000819670923/899d6a566ff3cd4b0d499b4486274243_normal.jpeg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': '1Atsuhimerose2',
#    'statuses_count': 166458,
#    'time_zone': 'Tokyo',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 32400,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Feb 24 00:50:30 +0000 2017',
#   'entities': {'hashtags': [{'indices': [13, 17], 'text': 'MIT'},
#     {'indices': [61, 72], 'text': 'ArcReactor'},
#     {'indices': [97, 104], 'text': 'Marvel'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 52554306,
#      'id_str': '52554306',
#      'indices': [21, 30],
#      'name': 'Jeopardy!',
#      'screen_name': 'Jeopardy'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 834928453166190592,
#   'id_str': '834928453166190592',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'The kid from #MIT ON @Jeopardy has an MIT sweatshirt with an #ArcReactor on it.  Fucking awesome #Marvel',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Apr 09 05:31:53 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Car enthusiast / Traveler / Beer drinker / Nerd / IMW / ITRCA / ITRexpo / QCPgear / SURJE.motorsports / ITR 98-0223',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 395,
#    'follow_request_sent': None,
#    'followers_count': 202,
#    'following': None,
#    'friends_count': 845,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 29929768,
#    'id_str': '29929768',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 2,
#    'location': 'Carlisle, Pa.',
#    'name': 'BrandonKuhn',
#    'notifications': None,
#    'profile_background_color': '1A1B1F',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/29929768/1486970765',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/835033599447609344/Ns9im131_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/835033599447609344/Ns9im131_normal.jpg',
#    'profile_link_color': '2FC2EF',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'brndons2k',
#    'statuses_count': 1622,
#    'time_zone': 'Quito',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Feb 23 18:03:16 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'atlas.media.mit.edu/en/',
#      'expanded_url': 'http://atlas.media.mit.edu/en/',
#      'indices': [115, 138],
#      'url': 'https://t.co/2tQmAstTWt'}],
#    'user_mentions': [{'id': 691353,
#      'id_str': '691353',
#      'indices': [7, 11],
#      'name': 'Joi Ito',
#      'screen_name': 'Joi'}]},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 834825970590818305,
#   'id_str': '834825970590818305',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'ja',
#   'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': '伊藤穣一さん(@Joi)が所長であることからも日本である程度認知されているMITのMediaLabのプロジェクト「OEC」がすごい。なかなか数字や文章からは読み取りにくい経済活動（輸出入、GDPなど）がビジュアライズされている。 https://t.co/2tQmAstTWt',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Sep 14 09:33:32 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '国際教養大学3年 秋入学 ギャップイヤー生｜カリフォルニア生まれ、静岡育ち。経営学専攻。海外ドラマとバレーボールが好き。アメリカ、Dickinson Collegeに留学中。Movie junkie, Amateur iphotographer. Father of #AIUパーカー',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'shugoalexohashi.hatenablog.com',
#        'expanded_url': 'http://shugoalexohashi.hatenablog.com/',
#        'indices': [0, 23],
#        'url': 'https://t.co/JLpNP71bjH'}]}},
#    'favourites_count': 9755,
#    'follow_request_sent': None,
#    'followers_count': 1075,
#    'following': None,
#    'friends_count': 911,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 822998198,
#    'id_str': '822998198',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ja',
#    'listed_count': 32,
#    'location': 'Carlisle, PA',
#    'name': '大橋修吾｜Shugo Ohashi',
#    'notifications': None,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/535383487092498432/GuVoyccB.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/535383487092498432/GuVoyccB.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/822998198/1483543833',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/816630865832869888/gX-6JgkQ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/816630865832869888/gX-6JgkQ_normal.jpg',
#    'profile_link_color': '09336B',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'A6BEBF',
#    'profile_text_color': 'FA9600',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'shugoohashi',
#    'statuses_count': 43651,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/JLpNP71bjH',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Feb 23 15:49:50 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/6dwWfmWjW9',
#      'expanded_url': 'https://twitter.com/divbyzero/status/834775231575109632/photo/1',
#      'id': 834775071084466176,
#      'id_str': '834775071084466176',
#      'indices': [97, 120],
#      'media_url': 'http://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'sizes': {'large': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'medium': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'small': {'h': 114, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 834775231575109632,
#      'source_status_id_str': '834775231575109632',
#      'source_user_id': 15810838,
#      'source_user_id_str': '15810838',
#      'type': 'photo',
#      'url': 'https://t.co/6dwWfmWjW9'}],
#    'symbols': [],
#    'urls': [{'display_url': 'courses.csail.mit.edu/6.857/2012/fil…',
#      'expanded_url': 'http://courses.csail.mit.edu/6.857/2012/files/H03-Cryptosystem-proposed-by-Nash.pdf',
#      'indices': [73, 96],
#      'url': 'https://t.co/luwMfF3dxi'}],
#    'user_mentions': [{'id': 15810838,
#      'id_str': '15810838',
#      'indices': [3, 13],
#      'name': 'Dave Richeson',
#      'screen_name': 'divbyzero'},
#     {'id': 1556664198,
#      'id_str': '1556664198',
#      'indices': [16, 28],
#      'name': 'Kyle Cranmer',
#      'screen_name': 'KyleCranmer'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/6dwWfmWjW9',
#      'expanded_url': 'https://twitter.com/divbyzero/status/834775231575109632/photo/1',
#      'id': 834775071084466176,
#      'id_str': '834775071084466176',
#      'indices': [97, 120],
#      'media_url': 'http://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'sizes': {'large': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'medium': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'small': {'h': 114, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 834775231575109632,
#      'source_status_id_str': '834775231575109632',
#      'source_user_id': 15810838,
#      'source_user_id_str': '15810838',
#      'type': 'photo',
#      'url': 'https://t.co/6dwWfmWjW9'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 834792393647984640,
#   'id_str': '834792393647984640',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 4,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Feb 23 14:41:39 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/6dwWfmWjW9',
#       'expanded_url': 'https://twitter.com/divbyzero/status/834775231575109632/photo/1',
#       'id': 834775071084466176,
#       'id_str': '834775071084466176',
#       'indices': [82, 105],
#       'media_url': 'http://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#       'sizes': {'large': {'h': 174, 'resize': 'fit', 'w': 1034},
#        'medium': {'h': 174, 'resize': 'fit', 'w': 1034},
#        'small': {'h': 114, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/6dwWfmWjW9'}],
#     'symbols': [],
#     'urls': [{'display_url': 'courses.csail.mit.edu/6.857/2012/fil…',
#       'expanded_url': 'http://courses.csail.mit.edu/6.857/2012/files/H03-Cryptosystem-proposed-by-Nash.pdf',
#       'indices': [58, 81],
#       'url': 'https://t.co/luwMfF3dxi'}],
#     'user_mentions': [{'id': 1556664198,
#       'id_str': '1556664198',
#       'indices': [1, 13],
#       'name': 'Kyle Cranmer',
#       'screen_name': 'KyleCranmer'}]},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/6dwWfmWjW9',
#       'expanded_url': 'https://twitter.com/divbyzero/status/834775231575109632/photo/1',
#       'id': 834775071084466176,
#       'id_str': '834775071084466176',
#       'indices': [82, 105],
#       'media_url': 'http://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#       'sizes': {'large': {'h': 174, 'resize': 'fit', 'w': 1034},
#        'medium': {'h': 174, 'resize': 'fit', 'w': 1034},
#        'small': {'h': 114, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/6dwWfmWjW9'}]},
#    'favorite_count': 7,
#    'favorited': False,
#    'geo': None,
#    'id': 834775231575109632,
#    'id_str': '834775231575109632',
#    'in_reply_to_screen_name': 'KyleCranmer',
#    'in_reply_to_status_id': 834599132597780481,
#    'in_reply_to_status_id_str': '834599132597780481',
#    'in_reply_to_user_id': 1556664198,
#    'in_reply_to_user_id_str': '1556664198',
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 4,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': ".@KyleCranmer Here's Nash's sentence handwritten. Source: https://t.co/luwMfF3dxi https://t.co/6dwWfmWjW9",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Aug 11 17:39:51 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "Mathematics professor at Dickinson College, author of Euler's Gem (@EulersGem), and editor of Math Horizons (@MathHorizons).",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'divisbyzero.com',
#         'expanded_url': 'http://divisbyzero.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/d9Ispqjwwy'}]}},
#     'favourites_count': 1849,
#     'follow_request_sent': None,
#     'followers_count': 9234,
#     'following': None,
#     'friends_count': 800,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 15810838,
#     'id_str': '15810838',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 572,
#     'location': 'Carlisle, PA',
#     'name': 'Dave Richeson',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/753906400/c0fa61113fe955400ad00618c2318481.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/753906400/c0fa61113fe955400ad00618c2318481.jpeg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15810838/1398196610',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3057810921/6d52467c49383aa4f9d27ceca931e918_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3057810921/6d52467c49383aa4f9d27ceca931e918_normal.jpeg',
#     'profile_link_color': '8C8C8C',
#     'profile_sidebar_border_color': '181A1E',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '2FC2EF',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'divbyzero',
#     'statuses_count': 10311,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/d9Ispqjwwy',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "RT @divbyzero: .@KyleCranmer Here's Nash's sentence handwritten. Source: https://t.co/luwMfF3dxi https://t.co/6dwWfmWjW9",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Apr 20 05:59:40 +0000 2013',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "Math PhD stud(ent) at Pitt • Math/Phys Tutor • OEIS editor • Author • I RT a lot. Striving for a finite Erdős number. I'm just having fun with it #H2P #StayWoke",
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'derektionary.webs.com',
#        'expanded_url': 'http://derektionary.webs.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/JihI6u680M'}]}},
#    'favourites_count': 129817,
#    'follow_request_sent': None,
#    'followers_count': 1314,
#    'following': None,
#    'friends_count': 168,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 1366290577,
#    'id_str': '1366290577',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 119,
#    'location': 'Pittsburgh, PA',
#    'name': 'Derek Orr',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000092840435/86618bae67fd2a0c28e5e41fcf01b392.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000092840435/86618bae67fd2a0c28e5e41fcf01b392.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366290577/1473821659',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/810156645242302464/gmBGleGZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/810156645242302464/gmBGleGZ_normal.jpg',
#    'profile_link_color': '0C45D4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Derektionary',
#    'statuses_count': 89029,
#    'time_zone': 'Bogota',
#    'translator_type': 'none',
#    'url': 'https://t.co/JihI6u680M',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Feb 23 14:47:24 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/6dwWfmWjW9',
#      'expanded_url': 'https://twitter.com/divbyzero/status/834775231575109632/photo/1',
#      'id': 834775071084466176,
#      'id_str': '834775071084466176',
#      'indices': [97, 120],
#      'media_url': 'http://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'sizes': {'large': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'medium': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'small': {'h': 114, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 834775231575109632,
#      'source_status_id_str': '834775231575109632',
#      'source_user_id': 15810838,
#      'source_user_id_str': '15810838',
#      'type': 'photo',
#      'url': 'https://t.co/6dwWfmWjW9'}],
#    'symbols': [],
#    'urls': [{'display_url': 'courses.csail.mit.edu/6.857/2012/fil…',
#      'expanded_url': 'http://courses.csail.mit.edu/6.857/2012/files/H03-Cryptosystem-proposed-by-Nash.pdf',
#      'indices': [73, 96],
#      'url': 'https://t.co/luwMfF3dxi'}],
#    'user_mentions': [{'id': 15810838,
#      'id_str': '15810838',
#      'indices': [3, 13],
#      'name': 'Dave Richeson',
#      'screen_name': 'divbyzero'},
#     {'id': 1556664198,
#      'id_str': '1556664198',
#      'indices': [16, 28],
#      'name': 'Kyle Cranmer',
#      'screen_name': 'KyleCranmer'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/6dwWfmWjW9',
#      'expanded_url': 'https://twitter.com/divbyzero/status/834775231575109632/photo/1',
#      'id': 834775071084466176,
#      'id_str': '834775071084466176',
#      'indices': [97, 120],
#      'media_url': 'http://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'sizes': {'large': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'medium': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'small': {'h': 114, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 834775231575109632,
#      'source_status_id_str': '834775231575109632',
#      'source_user_id': 15810838,
#      'source_user_id_str': '15810838',
#      'type': 'photo',
#      'url': 'https://t.co/6dwWfmWjW9'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 834776681269194753,
#   'id_str': '834776681269194753',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 4,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Feb 23 14:41:39 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/6dwWfmWjW9',
#       'expanded_url': 'https://twitter.com/divbyzero/status/834775231575109632/photo/1',
#       'id': 834775071084466176,
#       'id_str': '834775071084466176',
#       'indices': [82, 105],
#       'media_url': 'http://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#       'sizes': {'large': {'h': 174, 'resize': 'fit', 'w': 1034},
#        'medium': {'h': 174, 'resize': 'fit', 'w': 1034},
#        'small': {'h': 114, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/6dwWfmWjW9'}],
#     'symbols': [],
#     'urls': [{'display_url': 'courses.csail.mit.edu/6.857/2012/fil…',
#       'expanded_url': 'http://courses.csail.mit.edu/6.857/2012/files/H03-Cryptosystem-proposed-by-Nash.pdf',
#       'indices': [58, 81],
#       'url': 'https://t.co/luwMfF3dxi'}],
#     'user_mentions': [{'id': 1556664198,
#       'id_str': '1556664198',
#       'indices': [1, 13],
#       'name': 'Kyle Cranmer',
#       'screen_name': 'KyleCranmer'}]},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/6dwWfmWjW9',
#       'expanded_url': 'https://twitter.com/divbyzero/status/834775231575109632/photo/1',
#       'id': 834775071084466176,
#       'id_str': '834775071084466176',
#       'indices': [82, 105],
#       'media_url': 'http://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#       'sizes': {'large': {'h': 174, 'resize': 'fit', 'w': 1034},
#        'medium': {'h': 174, 'resize': 'fit', 'w': 1034},
#        'small': {'h': 114, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/6dwWfmWjW9'}]},
#    'favorite_count': 7,
#    'favorited': False,
#    'geo': None,
#    'id': 834775231575109632,
#    'id_str': '834775231575109632',
#    'in_reply_to_screen_name': 'KyleCranmer',
#    'in_reply_to_status_id': 834599132597780481,
#    'in_reply_to_status_id_str': '834599132597780481',
#    'in_reply_to_user_id': 1556664198,
#    'in_reply_to_user_id_str': '1556664198',
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 4,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': ".@KyleCranmer Here's Nash's sentence handwritten. Source: https://t.co/luwMfF3dxi https://t.co/6dwWfmWjW9",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Aug 11 17:39:51 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "Mathematics professor at Dickinson College, author of Euler's Gem (@EulersGem), and editor of Math Horizons (@MathHorizons).",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'divisbyzero.com',
#         'expanded_url': 'http://divisbyzero.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/d9Ispqjwwy'}]}},
#     'favourites_count': 1849,
#     'follow_request_sent': None,
#     'followers_count': 9234,
#     'following': None,
#     'friends_count': 800,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 15810838,
#     'id_str': '15810838',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 572,
#     'location': 'Carlisle, PA',
#     'name': 'Dave Richeson',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/753906400/c0fa61113fe955400ad00618c2318481.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/753906400/c0fa61113fe955400ad00618c2318481.jpeg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15810838/1398196610',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3057810921/6d52467c49383aa4f9d27ceca931e918_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3057810921/6d52467c49383aa4f9d27ceca931e918_normal.jpeg',
#     'profile_link_color': '8C8C8C',
#     'profile_sidebar_border_color': '181A1E',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '2FC2EF',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'divbyzero',
#     'statuses_count': 10311,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/d9Ispqjwwy',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': "RT @divbyzero: .@KyleCranmer Here's Nash's sentence handwritten. Source: https://t.co/luwMfF3dxi https://t.co/6dwWfmWjW9",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Jan 30 06:05:13 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "Dissident. NLP data janitor at Microsoft Research. Tsundoku expert. Language, computation and cognition. Opinions are not my employer's.",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 10544,
#    'follow_request_sent': None,
#    'followers_count': 1170,
#    'following': None,
#    'friends_count': 1287,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 244818919,
#    'id_str': '244818919',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 127,
#    'location': 'Bellevue, WA',
#    'name': 'Chris Brockett',
#    'notifications': None,
#    'profile_background_color': '1A1B1F',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/244818919/1461554986',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/834884059868209153/bwfqMi_0_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/834884059868209153/bwfqMi_0_normal.jpg',
#    'profile_link_color': '2FC2EF',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'chris_brockett',
#    'statuses_count': 13624,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Feb 23 14:42:03 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/6dwWfmWjW9',
#      'expanded_url': 'https://twitter.com/divbyzero/status/834775231575109632/photo/1',
#      'id': 834775071084466176,
#      'id_str': '834775071084466176',
#      'indices': [97, 120],
#      'media_url': 'http://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'sizes': {'large': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'medium': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'small': {'h': 114, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 834775231575109632,
#      'source_status_id_str': '834775231575109632',
#      'source_user_id': 15810838,
#      'source_user_id_str': '15810838',
#      'type': 'photo',
#      'url': 'https://t.co/6dwWfmWjW9'}],
#    'symbols': [],
#    'urls': [{'display_url': 'courses.csail.mit.edu/6.857/2012/fil…',
#      'expanded_url': 'http://courses.csail.mit.edu/6.857/2012/files/H03-Cryptosystem-proposed-by-Nash.pdf',
#      'indices': [73, 96],
#      'url': 'https://t.co/luwMfF3dxi'}],
#    'user_mentions': [{'id': 15810838,
#      'id_str': '15810838',
#      'indices': [3, 13],
#      'name': 'Dave Richeson',
#      'screen_name': 'divbyzero'},
#     {'id': 1556664198,
#      'id_str': '1556664198',
#      'indices': [16, 28],
#      'name': 'Kyle Cranmer',
#      'screen_name': 'KyleCranmer'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/6dwWfmWjW9',
#      'expanded_url': 'https://twitter.com/divbyzero/status/834775231575109632/photo/1',
#      'id': 834775071084466176,
#      'id_str': '834775071084466176',
#      'indices': [97, 120],
#      'media_url': 'http://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'sizes': {'large': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'medium': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'small': {'h': 114, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 834775231575109632,
#      'source_status_id_str': '834775231575109632',
#      'source_user_id': 15810838,
#      'source_user_id_str': '15810838',
#      'type': 'photo',
#      'url': 'https://t.co/6dwWfmWjW9'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 834775331953373184,
#   'id_str': '834775331953373184',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 4,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Feb 23 14:41:39 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/6dwWfmWjW9',
#       'expanded_url': 'https://twitter.com/divbyzero/status/834775231575109632/photo/1',
#       'id': 834775071084466176,
# ...
#       'id': 834775071084466176,
#       'id_str': '834775071084466176',
#       'indices': [82, 105],
#       'media_url': 'http://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#       'sizes': {'large': {'h': 174, 'resize': 'fit', 'w': 1034},
#        'medium': {'h': 174, 'resize': 'fit', 'w': 1034},
#        'small': {'h': 114, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/6dwWfmWjW9'}]},
#    'favorite_count': 7,
#    'favorited': False,
#    'geo': None,
#    'id': 834775231575109632,
#    'id_str': '834775231575109632',
#    'in_reply_to_screen_name': 'KyleCranmer',
#    'in_reply_to_status_id': 834599132597780481,
#    'in_reply_to_status_id_str': '834599132597780481',
#    'in_reply_to_user_id': 1556664198,
#    'in_reply_to_user_id_str': '1556664198',
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 4,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': ".@KyleCranmer Here's Nash's sentence handwritten. Source: https://t.co/luwMfF3dxi https://t.co/6dwWfmWjW9",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Aug 11 17:39:51 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "Mathematics professor at Dickinson College, author of Euler's Gem (@EulersGem), and editor of Math Horizons (@MathHorizons).",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'divisbyzero.com',
#         'expanded_url': 'http://divisbyzero.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/d9Ispqjwwy'}]}},
#     'favourites_count': 1849,
#     'follow_request_sent': None,
#     'followers_count': 9234,
#     'following': None,
#     'friends_count': 800,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 15810838,
#     'id_str': '15810838',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 572,
#     'location': 'Carlisle, PA',
#     'name': 'Dave Richeson',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/753906400/c0fa61113fe955400ad00618c2318481.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/753906400/c0fa61113fe955400ad00618c2318481.jpeg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15810838/1398196610',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3057810921/6d52467c49383aa4f9d27ceca931e918_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3057810921/6d52467c49383aa4f9d27ceca931e918_normal.jpeg',
#     'profile_link_color': '8C8C8C',
#     'profile_sidebar_border_color': '181A1E',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '2FC2EF',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'divbyzero',
#     'statuses_count': 10311,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/d9Ispqjwwy',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://tapbots.com/software/tweetbot/mac" rel="nofollow">Tweetbot for Mac</a>',
#   'text': "RT @divbyzero: .@KyleCranmer Here's Nash's sentence handwritten. Source: https://t.co/luwMfF3dxi https://t.co/6dwWfmWjW9",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Nov 11 18:29:07 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'math jokes, Python tricks, self retweets',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'tdhopper.com',
#        'expanded_url': 'http://tdhopper.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/Sczxl5t2da'}]}},
#    'favourites_count': 20910,
#    'follow_request_sent': None,
#    'followers_count': 3902,
#    'following': None,
#    'friends_count': 311,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 89249164,
#    'id_str': '89249164',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 287,
#    'location': 'Raleigh, NC',
#    'name': 'Tim Hopper 🔭',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/89249164/1469540167',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/783338261460713472/zYjnDHQ1_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/783338261460713472/zYjnDHQ1_normal.jpg',
#    'profile_link_color': 'FA743E',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'tdhopper',
#    'statuses_count': 36185,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/Sczxl5t2da',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Feb 23 14:41:39 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/6dwWfmWjW9',
#      'expanded_url': 'https://twitter.com/divbyzero/status/834775231575109632/photo/1',
#      'id': 834775071084466176,
#      'id_str': '834775071084466176',
#      'indices': [82, 105],
#      'media_url': 'http://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'sizes': {'large': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'medium': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'small': {'h': 114, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/6dwWfmWjW9'}],
#    'symbols': [],
#    'urls': [{'display_url': 'courses.csail.mit.edu/6.857/2012/fil…',
#      'expanded_url': 'http://courses.csail.mit.edu/6.857/2012/files/H03-Cryptosystem-proposed-by-Nash.pdf',
#      'indices': [58, 81],
#      'url': 'https://t.co/luwMfF3dxi'}],
#    'user_mentions': [{'id': 1556664198,
#      'id_str': '1556664198',
#      'indices': [1, 13],
#      'name': 'Kyle Cranmer',
#      'screen_name': 'KyleCranmer'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/6dwWfmWjW9',
#      'expanded_url': 'https://twitter.com/divbyzero/status/834775231575109632/photo/1',
#      'id': 834775071084466176,
#      'id_str': '834775071084466176',
#      'indices': [82, 105],
#      'media_url': 'http://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C5W3gRtXUAAevld.jpg',
#      'sizes': {'large': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'medium': {'h': 174, 'resize': 'fit', 'w': 1034},
#       'small': {'h': 114, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/6dwWfmWjW9'}]},
#   'favorite_count': 7,
#   'favorited': False,
#   'geo': None,
#   'id': 834775231575109632,
#   'id_str': '834775231575109632',
#   'in_reply_to_screen_name': 'KyleCranmer',
#   'in_reply_to_status_id': 834599132597780481,
#   'in_reply_to_status_id_str': '834599132597780481',
#   'in_reply_to_user_id': 1556664198,
#   'in_reply_to_user_id_str': '1556664198',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 4,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': ".@KyleCranmer Here's Nash's sentence handwritten. Source: https://t.co/luwMfF3dxi https://t.co/6dwWfmWjW9",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Aug 11 17:39:51 +0000 2008',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "Mathematics professor at Dickinson College, author of Euler's Gem (@EulersGem), and editor of Math Horizons (@MathHorizons).",
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'divisbyzero.com',
#        'expanded_url': 'http://divisbyzero.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/d9Ispqjwwy'}]}},
#    'favourites_count': 1849,
#    'follow_request_sent': None,
#    'followers_count': 9234,
#    'following': None,
#    'friends_count': 800,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 15810838,
#    'id_str': '15810838',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 572,
#    'location': 'Carlisle, PA',
#    'name': 'Dave Richeson',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/753906400/c0fa61113fe955400ad00618c2318481.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/753906400/c0fa61113fe955400ad00618c2318481.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15810838/1398196610',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/3057810921/6d52467c49383aa4f9d27ceca931e918_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3057810921/6d52467c49383aa4f9d27ceca931e918_normal.jpeg',
#    'profile_link_color': '8C8C8C',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '2FC2EF',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'divbyzero',
#    'statuses_count': 10311,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/d9Ispqjwwy',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Feb 22 04:19:14 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 24935003,
#      'id_str': '24935003',
#      'indices': [0, 6],
#      'name': 'Dave Jones',
#      'screen_name': 'mdj17'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 834256209054146564,
#   'id_str': '834256209054146564',
#   'in_reply_to_screen_name': 'mdj17',
#   'in_reply_to_status_id': 834252638879412224,
#   'in_reply_to_status_id_str': '834252638879412224',
#   'in_reply_to_user_id': 24935003,
#   'in_reply_to_user_id_str': '24935003',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': "@mdj17 That's idiotic numbers logic of fascist progreSSive movement. Just make shit up!  Reminds me of  MIT asshole Jonathan Gruber.",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Feb 14 21:12:47 +0000 2009',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Expatriate, Waiting for civil war.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 15840,
#    'follow_request_sent': None,
#    'followers_count': 330,
#    'following': None,
#    'friends_count': 42,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 20871807,
#    'id_str': '20871807',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 38,
#    'location': 'Enola, PA',
#    'name': 'Deplorable Metazip',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/20871807/1359088537',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/688377215587762177/ngdUDMLp_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/688377215587762177/ngdUDMLp_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Metazip',
#    'statuses_count': 27820,
#    'time_zone': 'Central Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -21600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Feb 20 02:41:13 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 833506764691738625,
#   'id_str': '833506764691738625',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.prestosports.com" rel="nofollow">PrestoSports</a>',
#   'text': "Men's Squash: Devils turn in outstanding performance but MIT slips away, 5-4, in their consolation final at the CSA Championships",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Jan 08 18:24:29 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Official account of Dickinson Athletics',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'dickinsonathletics.com',
#        'expanded_url': 'http://www.dickinsonathletics.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/MF17UnwjGY'}]}},
#    'favourites_count': 412,
#    'follow_request_sent': None,
#    'followers_count': 2677,
#    'following': None,
#    'friends_count': 132,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 18772960,
#    'id_str': '18772960',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 45,
#    'location': 'Carlisle, PA',
#    'name': 'Dickinson Red Devils',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/613749295141879808/K7O8hjfo.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/613749295141879808/K7O8hjfo.jpg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18772960/1429197769',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2385433618/squwl2m1842hfs4yzlp5_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2385433618/squwl2m1842hfs4yzlp5_normal.png',
#    'profile_link_color': 'E80E0E',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'DsonRedDevils',
#    'statuses_count': 5392,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/MF17UnwjGY',
#    'utc_offset': -18000,
#    'verified': False}}]

# %% [markdown]
# ### 4. Automate it - Hit the API and Parse the Result
#
# We are going to create a function to help us repeatedly hit the API, and parse the result into a readable JSON that contains the things that we are interested in, and still stores the raw tweet as an additional property. The returned object is a Python `dict` that we can easily parse into another dictionary to later store as a JSON. Raw JSONs returned from the API have a specific structure.
#
# It can be sometimes hard to read a raw JSON. I find it easy to use some online parsers like [this]( http://jsonparseronline.com/) to look at the structure of the JSON, and only access what we care about.
#
# Note: Remember we are limited to 450 every 15 minutes.

# %%
# Does pretty much what its long name suggests.
def get_lots_of_tweets( latlong ):
    # Create a dictionary to parse the JSON
    all_tweets = {}
    
    # We will be hitting the API a number of times within the total time
    total_time = 10
    
    # Everytime we hit the API we subtract time from the total
    remaining_seconds = total_time
    interval = 5
    while remaining_seconds > 0: # loop and run the function while remaining seconds is greater than zero
        added = 0
        # Hit the Twitter API using our function
        new_tweets = get_tweets_by_location(latlong) # we set latlong above!
        # Parse the resulting JSON, and save the rest of the raw content
        for tweet in new_tweets:
            tid = tweet['id']
            if tid not in all_tweets:
                properties = {}
                if tweet['coordinates'] != None:
                    properties['lat'] = tweet['coordinates']['coordinates'][0]
                    properties['lon'] = tweet['coordinates']['coordinates'][1]
                else:
                    properties['lat'] = None
                    properties['lon'] = None
                properties['location'] = tweet['user']['location'] #This will get us the location associated with the profile
                properties['tweet_id'] = tid
                properties['content'] = tweet['text']
                properties['user'] = tweet['user']['id']
                properties['raw_source'] = tweet
                properties['data_point'] = 'none'
                properties['time'] = tweet['created_at']
                all_tweets[ tid ] = properties
                added += 1
        print("At %d seconds, added %d new tweets, for a total of %d" % ( total_time - remaining_seconds, added, len( all_tweets )))
        # We wait a few seconds and hit the API again
        time.sleep(interval)
        remaining_seconds -= interval
    print(str(len(all_tweets)) + ' Tweets retrieved.')
    # We return the final dictionary to work with in Python
    return all_tweets

# %% [markdown]
# ### 5. Run the Twitter Scraper
#
# We need to call the functions, and save the JSONs into a location. In this case, I made a folder called **data**, where I am saving all the new JSONS. We can run the code continuously utilizing some loop, or we can use libraries like [threading](https://docs.python.org/3.6/library/threading.html).
#
# *Make sure you have a folder named **data** in the directory with your notebook! This function will save our collected datafiles to it when it finishes running.*

# %%
# This function executes the the functions over a given period of time
def run_all():
    # This is the number of times the code will be executed. In this case, just once. 
    starting = 1
    while starting > 0:
        # Sometimes the API returns some errors, killing the whole script, so we setup try/except to make sure it keeps running
        try:
            t = get_lots_of_tweets( latlong )
            # We name every file with the current time
            timestr = time.strftime("%Y%m%d-%H%M%S")
            # We write a new JSON into the target path
            with open( 'data/' + '%stweets.json' %(timestr), 'w' ) as f:
                f.write(json.dumps(t))
            # we can use a library like threading to execute the run function continuously.
            #threading.Timer(10, run).start()
            starting -= 1
        except:
            pass
    
run_all()
# Out:
# At 0 seconds, added 12 new tweets, for a total of 12
# At 5 seconds, added 0 new tweets, for a total of 12
# 12 Tweets retrieved.

# %% [markdown]
# ### 6. Let's Explore the Data we Saved to our Machine
#
# Let's look through the JSON we created and checkout some of the data we just downloaded. First, let's import a couple of additional libraries that will let us interact with our file system, use numpy and pandas, and create plots:

# %%
# Import some additional libraries that will allow us to plot and interact with the operating system
from os import listdir
from os.path import isfile, join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Next, let's explore our data a bit. This following function will allow us to perform a visual examination of what we downloaded from Twitter. Once we have collected some data, we can parse it, and visualize some of the results. Since some of the data is repeated, we can initialize some lists to check whether or not a tweet already exists, and add it to the list. We can then extract the useful information for our purposes, and store it in another list.
#
# Building on last week, we can do this in Pandas.

# %%
# Get the file names from a given directory
file_dir = "data" # Set this to where your JSON saved
# Get only the JSONs we have saved
onlyfiles = [ f for f in listdir(file_dir) if isfile(join(file_dir,f)) and not f.startswith('.')]

# create an empty dataframe with columns for each property
df_tweets = pd.DataFrame(columns = ['tweet_id', 'lat', 'lon', 'content','location','user','raw_source','data_point','time'])

# Loop through all the files
for file in onlyfiles:
    full_dir = join(file_dir,file) 
    with open(full_dir) as json_data:
        dict = json.load(json_data) # creates a Python dictionary of our json
        if not isinstance(dict, list):
            for key, val in dict.items():
                df_tweets.loc[key,val] = val
                
df_tweets
# Out:
#                               tweet_id   lat   lon  \
# 836939011939831810  836939011939831810  None  None
# 835556119506477056  835556119506477056  None  None
# 835129186964680706  835129186964680706  None  None
# 834953234577940480  834953234577940480  None  None
# 834928453166190592  834928453166190592  None  None
# 834825970590818305  834825970590818305  None  None
# 834792393647984640  834792393647984640  None  None
# 834776681269194753  834776681269194753  None  None
# 834775331953373184  834775331953373184  None  None
# 834775231575109632  834775231575109632  None  None
# 834256209054146564  834256209054146564  None  None
# 833506764691738625  833506764691738625  None  None
#
#                                                               content  \
# 836939011939831810  Hey @upstatement I love the work you did for t...
# 835556119506477056  @typeOneg_at danke, dass du dieses Erlebnis mi...
# 835129186964680706  @mpopp75 @guenschl @frauherr naja, hobbydies, ...
# 834953234577940480  RT @divbyzero: .@KyleCranmer Here's Nash's sen...
# 834928453166190592  The kid from #MIT ON @Jeopardy has an MIT swea...
# 834825970590818305  伊藤穣一さん(@Joi)が所長であることからも日本である程度認知されているMITのMedia...
# 834792393647984640  RT @divbyzero: .@KyleCranmer Here's Nash's sen...
# 834776681269194753  RT @divbyzero: .@KyleCranmer Here's Nash's sen...
# 834775331953373184  RT @divbyzero: .@KyleCranmer Here's Nash's sen...
# 834775231575109632  .@KyleCranmer Here's Nash's sentence handwritt...
# 834256209054146564  @mdj17 That's idiotic numbers logic of fascist...
# 833506764691738625  Men's Squash: Devils turn in outstanding perfo...
#
#                                  location                user  \
# 836939011939831810           Carlisle, PA           583831432
# 835556119506477056              Jonestown  833028106264915968
# 835129186964680706              Jonestown  833028106264915968
# 834953234577940480  Japan  Kagoshima city           235173460
# 834928453166190592          Carlisle, Pa.            29929768
# 834825970590818305           Carlisle, PA           822998198
# 834792393647984640         Pittsburgh, PA          1366290577
# 834776681269194753           Bellevue, WA           244818919
# 834775331953373184            Raleigh, NC            89249164
# 834775231575109632           Carlisle, PA            15810838
# 834256209054146564              Enola, PA            20871807
# 833506764691738625           Carlisle, PA            18772960
#
#                                                            raw_source  \
# 836939011939831810  {'created_at': 'Wed Mar 01 13:59:44 +0000 2017...
# 835556119506477056  {'created_at': 'Sat Feb 25 18:24:37 +0000 2017...
# 835129186964680706  {'created_at': 'Fri Feb 24 14:08:08 +0000 2017...
# 834953234577940480  {'created_at': 'Fri Feb 24 02:28:58 +0000 2017...
# 834928453166190592  {'created_at': 'Fri Feb 24 00:50:30 +0000 2017...
# 834825970590818305  {'created_at': 'Thu Feb 23 18:03:16 +0000 2017...
# 834792393647984640  {'created_at': 'Thu Feb 23 15:49:50 +0000 2017...
# 834776681269194753  {'created_at': 'Thu Feb 23 14:47:24 +0000 2017...
# 834775331953373184  {'created_at': 'Thu Feb 23 14:42:03 +0000 2017...
# 834775231575109632  {'created_at': 'Thu Feb 23 14:41:39 +0000 2017...
# 834256209054146564  {'created_at': 'Wed Feb 22 04:19:14 +0000 2017...
# 833506764691738625  {'created_at': 'Mon Feb 20 02:41:13 +0000 2017...
#
#                    data_point                            time
# 836939011939831810       none  Wed Mar 01 13:59:44 +0000 2017
# 835556119506477056       none  Sat Feb 25 18:24:37 +0000 2017
# 835129186964680706       none  Fri Feb 24 14:08:08 +0000 2017
# 834953234577940480       none  Fri Feb 24 02:28:58 +0000 2017
# 834928453166190592       none  Fri Feb 24 00:50:30 +0000 2017
# 834825970590818305       none  Thu Feb 23 18:03:16 +0000 2017
# 834792393647984640       none  Thu Feb 23 15:49:50 +0000 2017
# 834776681269194753       none  Thu Feb 23 14:47:24 +0000 2017
# 834775331953373184       none  Thu Feb 23 14:42:03 +0000 2017
# 834775231575109632       none  Thu Feb 23 14:41:39 +0000 2017
# 834256209054146564       none  Wed Feb 22 04:19:14 +0000 2017
# 833506764691738625       none  Mon Feb 20 02:41:13 +0000 2017

# %% [markdown]
# ### 7. Summarize, Group, and Plot the Dataset
#
# Next let's summarize and group our data, and create some plots.
#
# **A** - First, group by the user location. This is not lat/lon, but rather the information the individual has input on their profile.
#
# When you give people the power to input their own location, you get an assortment of 'creative' responses!

# %%
df_tweets.dtypes
# Out:
# tweet_id      object
# lat           object
# lon           object
# content       object
# location      object
# user          object
# raw_source    object
# data_point    object
# time          object
# dtype: object

# %%
df_tweets['location'].unique()
# Out:
# array(['Carlisle, PA', 'Jonestown', 'Japan  Kagoshima city',
#        'Carlisle, Pa.', 'Pittsburgh, PA', 'Bellevue, WA', 'Raleigh, NC',
#        'Enola, PA', 'York,PA', 'Lewisberry, PA', '', 'Harrisburg, PA',
#        'York, PA', 'West York, PA', '대한민국',
#        'Harrisburg, Pennsylvania, USA', 'somewheretrynabegreat',
#        'Harrisburg,PA', 'Baltimore, MD', 'Middletown, PA'], dtype=object)

# %% [markdown]
# Now let's do some grouping and sorting. We are using Pandas to do our analysis, much like last week.

# %%
grouped_tweets = df_tweets.groupby('location')
count_tweets = grouped_tweets['location'].count()
df_count_tweets = count_tweets.to_frame()
df_count_tweets.columns = ['Count']
df_count_tweets.index.names = ['Location']
df_count_tweets.sort_index()
# Out:
#                        Count
# Location
# Bellevue, WA               1
# Carlisle, PA               4
# Carlisle, Pa.              1
# Enola, PA                  1
# Japan  Kagoshima city      1
# Jonestown                  2
# Pittsburgh, PA             1
# Raleigh, NC                1

# %% [markdown]
# Let's create a pie chart of these using matplotlib.

# %%
# Create a list of colors (from iWantHue)
colors = ["#d1d4ce","#282723","#76a44a","#565b55",
          "#cc54bc","#4bad89","#d84577","#4eacd7",
          "#cf4e33","#894ea8","#cf8c42","#d58cc9",
          "#737632","#9f4b75","#c36960"]

# Create a pie chart
plt.pie( df_count_tweets['Count'], labels=df_count_tweets.index.get_values(), shadow=False, colors=colors)

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# There are quite a few duplicates that we can clearly see, you will likely want to clean this data to rectify this.

# %% [markdown]
# **B** - Next, let's find how many actually have a location and put them on a scatterplot. To do this, we need to find first the rows where lat and long are not None, and then create the plot from just that subset of the data. Let's give it a go.

# %%
# Create a filter from df_tweets filtering only those that have values for lat and lon
df_tweets_with_location = df_tweets[df_tweets.lon.notnull() & df_tweets.lat.notnull()]
df_tweets_with_location
# Out:
# Empty DataFrame
# Columns: [tweet_id, lat, lon, content, location, user, raw_source, data_point, time]
# Index: []

# %%
# Use a scatter plot to make a quick visualization of the data points
# NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-1dff57db92fa> in <module>()
#       1 # Use a scatter plot to make a quick visualization of the data points
#       2 # NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
# ----> 3 plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
#       4 plt.show()
#
# //anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3433                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3434                          linewidths=linewidths, verts=verts,
# -> 3435                          edgecolors=edgecolors, data=data, **kwargs)
#    3436     finally:
#    3437         ax._hold = washold
#
# //anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# //anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3993         maskargs = x, y, s, c, colors, edgecolors, linewidths
#    3994         x, y, s, c, colors, edgecolors, linewidths =\
# -> 3995             cbook.delete_masked_points(*maskargs)
#    3996
#    3997         scales = s   # Renamed for readability below.
#
# //anaconda/lib/python3.6/site-packages/matplotlib/cbook.py in delete_masked_points(*args)
#    1834         return ()
#    1835     if (is_string_like(args[0]) or not iterable(args[0])):
# -> 1836         raise ValueError("First argument must be a sequence")
#    1837     nrecs = len(args[0])
#    1838     margs = []
#
# ValueError: First argument must be a sequence

# %% [markdown]
# ### 8. Clean the Data
#
# **Clean the Locations** - You saw above that we had a bunch of locations that were very similar. Here, we could use [replace](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.replace.html). For example, we could replace all the variations of **York, PA** with a singular string using something like the following:

# %%
# List of variations of York
variations_of_Carlisle = ['Carliste, PA','Carlisle, Pa.']
    #,'York, Pennsylvania','York, Pa','41 W Market Street York, Pa','york P.a. ','York, Pa.']

df_tweets['location'].replace(variations_of_Carlisle, 'Carlisle, PA')
# Out:
# 836939011939831810             Carlisle, PA
# 835556119506477056                Jonestown
# 835129186964680706                Jonestown
# 834953234577940480    Japan  Kagoshima city
# 834928453166190592             Carlisle, PA
# 834825970590818305             Carlisle, PA
# 834792393647984640           Pittsburgh, PA
# 834776681269194753             Bellevue, WA
# 834775331953373184              Raleigh, NC
# 834775231575109632             Carlisle, PA
# 834256209054146564                Enola, PA
# 833506764691738625             Carlisle, PA
# Name: location, dtype: object

# %% [markdown]
# **Remove Duplicates** - Make sure that we don't get tweets plotted more than once. How would you make sure to only plot unique tweets? We can maybe use [drop_duplicates](http://chrisalbon.com/python/pandas_delete_duplicates.html)

# %% [markdown]
# ### 9. Exporting your Data to CSV
#
# Exporting your dataset is easy, you can use **to_csv()**. This [Stack Exchange](http://stackoverflow.com/questions/16923281/pandas-writing-dataframe-to-csv-file) page will help you.

# %%
df_tweets.to_csv('twitter_data.csv', sep=',', encoding='utf-8')

# %% [markdown]
# ### Problem Set 3 - Extend What You Have Learned
#
# Now that you know how to scrape data from Twitter, let's extend the exercise a little so you can show us what you know. This time you will set up the scraper to get data around MIT and scrape data for 20 minutes. Then you will visualize it with  and visualize. Think about what you would need to change to do that.
#
# Once you have the new JSON file of Boston tweets you should a pie chart and scatterplot of your collected tweets. When you are creating your dataset, you should get at least two different attributes returned by the Twitter API (we got many of them above, so base it off of that example). Atleast one of them should be the tweet id. Make sure you remove and duplicate tweets (if any). Expanding on the above, then save the data to a CSV.
#
# Make sure you get your own Twitter Key.
#
# #### Deliverables
#
# **1** - Using the Twitter REST API, collect Tweets from Boston for 30 min. Note how you set the time in the above example (in the **run_all()** function), it was in seconds. How would you do that here?
#
# **2** - Create a Pie Chart showing a summary of tweets by user location. Please clean up the data so that multiple variations of the same location name are replaced with one variation.
#
# **3** - Create a Scatterplot showing all of the tweets that had a latitude and longitude.
#
# **4** - Pick a search term, such as *Trump* or *#Trump* and collect 15 minutes of tweets on it. Use the same lat/lon for Boston as you used above.
#
# **5** - Export the entirety of your scraped Twitter datasets (one with a search term, one without) to two CSV files. We will be checking this CSV file for duplicates. So clean your file.
#
# ### What to Give Us on Stellar
#
# 1 - Create a new Jupyter notebook that contains your scraper code. You can copy much of this one, but customize it. Submit the new Jupyter notebook, which includes your pie chart and scatterplot.
#
# 2 - Your final CSV files.
