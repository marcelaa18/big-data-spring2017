# %% [markdown]
# Big Data And Society: Problem Set 3
# =====

# %% [markdown]
# # APIs and Data Scraping: Getting Twitter Data

# %% [markdown]
# ### 0. Set up a Twitter Application
#
# This week we are going to scrape data from the Twitter API and make some plots! We are going to use the Twitter REST API, which lets us query and retreive samples of Tweets. To do this, you need API keys that are associated with your account. Your API keys are secret and unique to you and only you, and they gives you access to Twitter data through the API.
#
# There are a couple of ways to get Twitter data, the REST API is just one of them. The others are to set up a Streamer (which streams real time tweets), or to access the Firehose (this means everything!). Read [this article](https://brightplanet.com/2013/06/twitter-firehose-vs-twitter-api-whats-the-difference-and-why-should-you-care/) for a nice comparison between the methods.
#
# The Twitter REST API is best place to start and what we will use in class. Follow the following steps to get your keys.
#
# * Create a twitter account if you do not already have one.
# * Go to [https://apps.twitter.com/](https://apps.twitter.com/) and log in with your twitter credentials.
# * Click **"Create New App"** in the upper right corner
# * Fill out the form, give it a name like **data_getter_yourname** and a description, agree to the terms, and click **"Create your Twitter application"** *Note: The form will ask for a website. You can put the github.io page you made as the URL. **It is OK for your callback URL to be blank.***
# * In the next page, click on **Keys and Access Tokens** tab, and copy your "Consumer Key (API Key)" and "Consumer Key (API Secret)".
#
# We need a Python file that will contain the **Twitter** keys. It is never a good idea to host these keys on a public website like **github**, so one way to keep them private is importing the keys as a variable from a separate, untracked file. Open your text editor, and in the materials for the week, *PASTE* these keys into the **twitter-keys.py** file and save the file. Using this method, we can then import the keys and use them on a repeated basis, and we can choose not to put this file on Github. **Make sure they are saved as strings!**
#
# **!!IMPORTANT NOTE!! NEVER SAVE YOUR TWITTER_KEY.PY FILE TO GITHUB. IF YOU DO, PEOPLE CAN SEE YOUR KEYS AND USE THEM. KEEP THESE ON YOUR MACHINE.**

# %% [markdown]
# ### 1. Importing the Libraries and Twitter Keys
#
# We will be using **Twython**, a Python library that provides wrappers around Twitter's API. To install **Twython** on a terminal or the command line, run the following command:
#
# ```
# pip install twython
# ```
#
# We also need to import the keys we just got from Twitter to be accessible to our code. View the contents of **twitter_key.py** to see your keys. These should both be strings.
#
# ```
# # In the file you should define two variables:
# api_key = "your twitter key"
# api_secret = "your twitter secret"
# ```
#
# Import the libraries:

# %%
# Import libraries
import json
import time
import threading
from datetime import datetime
from twython import Twython

# Imports the keys from the python file
from twitter_key import api_key, api_secret

# %% [markdown]
# ### 2. Set Up Twython, Get an OAuth2 Token, and Create your Twython Object
#
# In this next step, assign the keys to variables and set up our instance of Twython to work with your account.
#
# Doing this requires our authentication with Twitter using our keys. Twitter uses something called [OAuth](https://dev.twitter.com/oauth) for API authentication. There are two types of OAuth authentication. OAuth1 provides user authentication to the API, and is required to post tweets and issue requests on behalf of users. OAuth 2 is [application-only authentication](https://dev.twitter.com/oauth/application-only), and has higher rate limits but doesn't allow you to post on users behalf. Because we can get more tweets using it, we are going to use OAuth2.
#
# **OAuth 2 requires a Third Access token you must request using the API. This next step will set everything up for us.**
#
# In the last part of this, we create a **Twython** object and call it **my_twython**; this object simplifies the access to the [Twitter API](https://dev.twitter.com/overview/documentation), and provides methods for accessing the API’s endpoints. The first function fetches tweets with a given query at a given lat-long. We will be using the search parameters to hit the APIs endpoint. We need to provide the lat/lon of the centroid of the area we want to query, maximum number of tweets to return, and area within the centroid to search for, among others.

# %%
# Assigns the keys to the variables
APP_KEY = api_key
APP_SECRET = api_secret

# Create a Twython object called Twitter
# Set this up using your Twitter Keys
# Say we are going to use OAuth 2
twython_setup = Twython(APP_KEY, APP_SECRET, oauth_version=2)

# Get an OAuth2 access token, save as variable so we can launch our 
OAUTH2_ACCESS_TOKEN = twython_setup.obtain_access_token()

# Create a Twython Object we will use for our access to the API
my_twython = Twython(APP_KEY, access_token=OAUTH2_ACCESS_TOKEN)

# %% [markdown]
# For reference, the Twython documentation and all available commands can be found here. [https://twython.readthedocs.io/en/latest/usage/starting_out.html](https://twython.readthedocs.io/en/latest/usage/starting_out.html)

# %% [markdown]
# ### 3. Query the Twitter API to get Tweets at a Location
#
# Next, let's do a search and get some tweets! Specifically, set up a function that will use the **search** API. Read more about the **search** API [here](https://dev.twitter.com/rest/reference/get/search/tweets).
#
# The **Search API** can take many parameters for querying tweets. Twitter has a nice page of what you can use as query parameters here [https://dev.twitter.com/rest/public/search](https://dev.twitter.com/rest/public/search).
#
# The Twitter API has rate limits that limit how quickly you can download data. This is to try to lighten the load on their servers. We are using the Search API with **OAuth2 (Application) Access** - which limits us to **450 in 15 minutes** Read about the [Rate Limits](https://dev.twitter.com/rest/public/rate-limiting) here. This means, in our following steps, always follow the guideline that you will not be able to get more than 450 tweets in 15 minutes, or Twitter might lock your access.

# %%
# Input the search term you want to search on
search_term='' # SET A SEARCH TERM
# CAN LEAVE search_term BLANK IF YOU WANT ALL TWEETS NEAR A SPECIFIC LOCATION
# Setup a Lat Lon
latlong=[42.361145,-71.057083] # Boston, MA
# Setup a search distance
distance='25mi'
# Set result type (can be 'recent', 'popular', or 'mixed')
type_of_result='recent'
# Set number of results (up to 100, remember you can only get 450 in 15 minutes)
number_of_tweets=15


# Fetches tweets with a given query at a given lat-long.
def get_tweets_by_location( latlong=None ):
    # Uses the search function to hit the APIs endpoints and look for recent tweets within the area
    results = my_twython.search(q=search_term, geocode=str(latlong[0])+','+str(latlong[1])+','+ distance, result_type=type_of_result, count=number_of_tweets)
    # Returns only the statuses from the resulting JSON
    return results['statuses']

# test run our function
get_tweets_by_location(latlong)
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 19:36:39 +0000 2017',
#   'entities': {'hashtags': [{'indices': [15, 21], 'text': 'ICYMI'},
#     {'indices': [54, 66], 'text': 'DataScience'}],
#    'symbols': [],
#    'urls': [{'display_url': 'buff.ly/2lhE6Hd',
#      'expanded_url': 'http://buff.ly/2lhE6Hd',
#      'indices': [97, 120],
#      'url': 'https://t.co/mJQ8or1xeg'}],
#    'user_mentions': [{'id': 20167623,
#      'id_str': '20167623',
#      'indices': [3, 13],
#      'name': 'KDnuggets',
#      'screen_name': 'kdnuggets'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 837023797614153730,
#   'id_str': '837023797614153730',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 17,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 01 17:35:11 +0000 2017',
#    'entities': {'hashtags': [{'indices': [0, 6], 'text': 'ICYMI'},
#      {'indices': [39, 51], 'text': 'DataScience'}],
#     'media': [{'display_url': 'pic.twitter.com/yJtsohsVQY',
#       'expanded_url': 'https://twitter.com/kdnuggets/status/836993230071873544/photo/1',
#       'id': 836993227567869952,
#       'id_str': '836993227567869952',
#       'indices': [106, 129],
#       'media_url': 'http://pbs.twimg.com/media/C52Y5-iXMAAv4dj.png',
#       'media_url_https': 'https://pbs.twimg.com/media/C52Y5-iXMAAv4dj.png',
#       'sizes': {'large': {'h': 640, 'resize': 'fit', 'w': 640},
#        'medium': {'h': 640, 'resize': 'fit', 'w': 640},
#        'small': {'h': 640, 'resize': 'fit', 'w': 640},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/yJtsohsVQY'}],
#     'symbols': [],
#     'urls': [{'display_url': 'buff.ly/2lhE6Hd',
#       'expanded_url': 'http://buff.ly/2lhE6Hd',
#       'indices': [82, 105],
#       'url': 'https://t.co/mJQ8or1xeg'}],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/yJtsohsVQY',
#       'expanded_url': 'https://twitter.com/kdnuggets/status/836993230071873544/photo/1',
#       'id': 836993227567869952,
#       'id_str': '836993227567869952',
#       'indices': [106, 129],
#       'media_url': 'http://pbs.twimg.com/media/C52Y5-iXMAAv4dj.png',
#       'media_url_https': 'https://pbs.twimg.com/media/C52Y5-iXMAAv4dj.png',
#       'sizes': {'large': {'h': 640, 'resize': 'fit', 'w': 640},
#        'medium': {'h': 640, 'resize': 'fit', 'w': 640},
#        'small': {'h': 640, 'resize': 'fit', 'w': 640},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/yJtsohsVQY'},
#      {'display_url': 'pic.twitter.com/yJtsohsVQY',
#       'expanded_url': 'https://twitter.com/kdnuggets/status/836993230071873544/photo/1',
#       'id': 836993227047780367,
#       'id_str': '836993227047780367',
#       'indices': [106, 129],
#       'media_url': 'http://pbs.twimg.com/media/C52Y58mXQA8yDA6.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C52Y58mXQA8yDA6.jpg',
#       'sizes': {'large': {'h': 599, 'resize': 'fit', 'w': 600},
#        'medium': {'h': 599, 'resize': 'fit', 'w': 600},
#        'small': {'h': 599, 'resize': 'fit', 'w': 600},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/yJtsohsVQY'}]},
#    'favorite_count': 7,
#    'favorited': False,
#    'geo': None,
#    'id': 836993230071873544,
#    'id_str': '836993230071873544',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 17,
#    'retweeted': False,
#    'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>',
#    'text': '#ICYMI Gartner 2017 Magic Quadrant for #DataScience Platforms: gainers and losers https://t.co/mJQ8or1xeg https://t.co/yJtsohsVQY',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Feb 05 17:37:26 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Covering #Analytics, #BigData, #DataMining, #DataScience #MachineLearning, #DeepLearning.  Founded by Gregory Piatetsky-Shapiro.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'kdnuggets.com',
#         'expanded_url': 'http://www.kdnuggets.com/',
#         'indices': [0, 22],
#         'url': 'http://t.co/aWUY84onbG'}]}},
#     'favourites_count': 329,
#     'follow_request_sent': None,
#     'followers_count': 76230,
#     'following': None,
#     'friends_count': 419,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 20167623,
#     'id_str': '20167623',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 5093,
#     'location': 'Brookline, MA, USA',
#     'name': 'KDnuggets',
#     'notifications': None,
#     'profile_background_color': '0099B9',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000050609482/c32d3d654da4eb7c0518e7bba2609522.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000050609482/c32d3d654da4eb7c0518e7bba2609522.jpeg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/20167623/1476546748',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/795788806008041473/0nTPcRja_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/795788806008041473/0nTPcRja_normal.jpg',
#     'profile_link_color': '0099B9',
#     'profile_sidebar_border_color': '5ED4DC',
#     'profile_sidebar_fill_color': '95E8EC',
#     'profile_text_color': '3C3940',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'kdnuggets',
#     'statuses_count': 36131,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'regular',
#     'url': 'http://t.co/aWUY84onbG',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @kdnuggets: #ICYMI Gartner 2017 Magic Quadrant for #DataScience Platforms: gainers and losers https://t.co/mJQ8or1xeg https://t.co/yJtso…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Apr 25 14:51:38 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '#Blockchain #FinTech #DigitalTransformation The best projects require the best people. We have access to both. From Director to Developer - discretion assured.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'silicontalent.co.uk',
#        'expanded_url': 'http://www.silicontalent.co.uk',
#        'indices': [0, 23],
#        'url': 'https://t.co/WIfWIjqhtC'}]}},
#    'favourites_count': 1523,
#    'follow_request_sent': None,
#    'followers_count': 3076,
#    'following': None,
#    'friends_count': 2781,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 724611831785000960,
#    'id_str': '724611831785000960',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1999,
#    'location': 'London, England',
#    'name': 'Silicon Talent',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/724611831785000960/1465041814',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/731180456775958528/2ycYrtmV_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/731180456775958528/2ycYrtmV_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'silicontalent',
#    'statuses_count': 14945,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/WIfWIjqhtC',
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 19:36:39 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'trib.al/IBt0RrH',
#      'expanded_url': 'http://trib.al/IBt0RrH',
#      'indices': [90, 113],
#      'url': 'https://t.co/xacxYAm90y'}],
#    'user_mentions': [{'id': 15808647,
#      'id_str': '15808647',
#      'indices': [3, 14],
#      'name': 'MIT Tech Review',
#      'screen_name': 'techreview'},
#     {'id': 19103481,
#      'id_str': '19103481',
#      'indices': [83, 88],
#      'name': 'Uber',
#      'screen_name': 'Uber'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 837023797135966212,
#   'id_str': '837023797135966212',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 7,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 01 18:36:22 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'trib.al/IBt0RrH',
#       'expanded_url': 'http://trib.al/IBt0RrH',
#       'indices': [74, 97],
#       'url': 'https://t.co/xacxYAm90y'}],
#     'user_mentions': [{'id': 19103481,
#       'id_str': '19103481',
#       'indices': [67, 72],
#       'name': 'Uber',
#       'screen_name': 'Uber'}]},
#    'favorite_count': 5,
#    'favorited': False,
#    'geo': None,
#    'id': 837008627290554368,
#    'id_str': '837008627290554368',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 7,
#    'retweeted': False,
#    'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#    'text': 'The shortest month of the year yielded a long list of troubles for @Uber. https://t.co/xacxYAm90y',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Aug 11 14:31:16 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'MIT Technology Review equips its audiences with the intelligence to understand a world shaped by technology.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'technologyreview.com',
#         'expanded_url': 'http://www.technologyreview.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/JWwse7vGcG'}]}},
#     'favourites_count': 7516,
#     'follow_request_sent': None,
#     'followers_count': 646707,
#     'following': None,
#     'friends_count': 3320,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 15808647,
#     'id_str': '15808647',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 15937,
#     'location': 'Cambridge, MA',
#     'name': 'MIT Tech Review',
#     'notifications': None,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/692500348/1db869569770d1c9db8e0c5aca8380f3.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/692500348/1db869569770d1c9db8e0c5aca8380f3.jpeg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15808647/1468855196',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/731132378001879040/HWk2Eaxg_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/731132378001879040/HWk2Eaxg_normal.jpg',
#     'profile_link_color': '91D2FA',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'C0C0C0',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'techreview',
#     'statuses_count': 44321,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'regular',
#     'url': 'http://t.co/JWwse7vGcG',
#     'utc_offset': -18000,
#     'verified': True}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @techreview: The shortest month of the year yielded a long list of troubles for @Uber. https://t.co/xacxYAm90y',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Apr 13 21:18:34 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'applecakeplanet.com',
#        'expanded_url': 'http://applecakeplanet.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/nUO9rFKR4j'}]}},
#    'favourites_count': 6115,
#    'follow_request_sent': None,
#    'followers_count': 1886,
#    'following': None,
#    'friends_count': 2796,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 281729697,
#    'id_str': '281729697',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 145,
#    'location': 'nyc',
#    'name': 'Applecake Planet',
#    'notifications': None,
#    'profile_background_color': '0099B9',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/606358569/t4olv7m6ja0b0c1qnqlt.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/606358569/t4olv7m6ja0b0c1qnqlt.jpeg',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2242462551/final_logo1_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2242462551/final_logo1_normal.jpg',
#    'profile_link_color': '0099B9',
#    'profile_sidebar_border_color': '65B0DA',
#    'profile_sidebar_fill_color': '7AC3EE',
#    'profile_text_color': '3D1957',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'applecakeplanet',
#    'statuses_count': 15800,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/nUO9rFKR4j',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 19:36:38 +0000 2017',
#   'entities': {'hashtags': [{'indices': [71, 80], 'text': 'employee'},
#     {'indices': [81, 92], 'text': 'WorkTrends'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 22634164,
#      'id_str': '22634164',
#      'indices': [3, 15],
#      'name': 'Meghan M. Biro',
#      'screen_name': 'MeghanMBiro'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 837023795831435264,
#   'id_str': '837023795831435264',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 3,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 01 18:43:04 +0000 2017',
#    'entities': {'hashtags': [{'indices': [54, 63], 'text': 'employee'},
#      {'indices': [64, 75], 'text': 'WorkTrends'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 2,
#    'favorited': False,
#    'geo': None,
#    'id': 837010315279642624,
#    'id_str': '837010315279642624',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 3,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': 'A2: A strong assessment is likely to produce a strong #employee #WorkTrends',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Mar 03 15:26:39 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'CEO @TalentCulture | #WorkTrends Wed 1pmET | @Forbes @Entrepreneur @HuffingtonPost | #HR #Tech #Socbiz #Entrepreneur #FutureOfWork',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'talentculture.com',
#         'expanded_url': 'http://www.talentculture.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/MzzId6vQLu'}]}},
#     'favourites_count': 27328,
#     'follow_request_sent': None,
#     'followers_count': 135595,
#     'following': None,
#     'friends_count': 98175,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 22634164,
#     'id_str': '22634164',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 7036,
#     'location': 'Cambridge, MA ',
#     'name': 'Meghan M. Biro',
#     'notifications': None,
#     'profile_background_color': '009DDC',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/446495737635819521/XzyQ7TRg.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/446495737635819521/XzyQ7TRg.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/22634164/1359909277',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/745596307864174594/YKw8yQNt_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/745596307864174594/YKw8yQNt_normal.jpg',
#     'profile_link_color': '31A621',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DEF6FF',
#     'profile_text_color': '3D1957',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'MeghanMBiro',
#     'statuses_count': 218981,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/MzzId6vQLu',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @MeghanMBiro: A2: A strong assessment is likely to produce a strong #employee #WorkTrends',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Jun 26 22:47:51 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Tech writer and cl racer.. #iWork4HPE',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 171,
#    'follow_request_sent': None,
#    'followers_count': 315,
#    'following': None,
#    'friends_count': 1019,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 324606654,
#    'id_str': '324606654',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 36,
#    'location': 'India',
#    'name': 'Prasoon Suresh',
#    'notifications': None,
#    'profile_background_color': '59BEE4',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/670722409/7b1cad0896d22d75b85f5f86fc69b59f.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/670722409/7b1cad0896d22d75b85f5f86fc69b59f.jpeg',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2326330471/eYArKi20_normal',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2326330471/eYArKi20_normal',
#    'profile_link_color': '8FCAE0',
#    'profile_sidebar_border_color': '4BB7DF',
#    'profile_sidebar_fill_color': '191F22',
#    'profile_text_color': '4BB7DF',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'PrasoonSuresh',
#    'statuses_count': 1047,
#    'time_zone': 'Asia/Calcutta',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 19800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 19:36:38 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/smIXbl2DQR',
#      'expanded_url': 'https://twitter.com/MrEdTrain/status/836942413096697857/photo/1',
#      'id': 836942406503264256,
#      'id_str': '836942406503264256',
#      'indices': [117, 140],
#      'media_url': 'http://pbs.twimg.com/media/C51qrzUWcAAEPis.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C51qrzUWcAAEPis.jpg',
#      'sizes': {'large': {'h': 1024, 'resize': 'fit', 'w': 600},
#       'medium': {'h': 1024, 'resize': 'fit', 'w': 600},
#       'small': {'h': 680, 'resize': 'fit', 'w': 398},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 836942413096697857,
#      'source_status_id_str': '836942413096697857',
#      'source_user_id': 2903166449,
#      'source_user_id_str': '2903166449',
#      'type': 'photo',
#      'url': 'https://t.co/smIXbl2DQR'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 2903166449,
#      'id_str': '2903166449',
#      'indices': [3, 13],
#      'name': '☘️EddieMAGATrump🇺🇸',
#      'screen_name': 'MrEdTrain'},
#     {'id': 818876014390603776,
#      'id_str': '818876014390603776',
#      'indices': [92, 99],
#      'name': 'Melania Trump',
#      'screen_name': 'FLOTUS'},
#     {'id': 25073877,
#      'id_str': '25073877',
#      'indices': [100, 116],
#      'name': 'Donald J. Trump',
#      'screen_name': 'realDonaldTrump'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/smIXbl2DQR',
#      'expanded_url': 'https://twitter.com/MrEdTrain/status/836942413096697857/photo/1',
#      'id': 836942406503264256,
#      'id_str': '836942406503264256',
#      'indices': [117, 140],
#      'media_url': 'http://pbs.twimg.com/media/C51qrzUWcAAEPis.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C51qrzUWcAAEPis.jpg',
#      'sizes': {'large': {'h': 1024, 'resize': 'fit', 'w': 600},
#       'medium': {'h': 1024, 'resize': 'fit', 'w': 600},
#       'small': {'h': 680, 'resize': 'fit', 'w': 398},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 836942413096697857,
#      'source_status_id_str': '836942413096697857',
#      'source_user_id': 2903166449,
#      'source_user_id_str': '2903166449',
#      'type': 'photo',
#      'url': 'https://t.co/smIXbl2DQR'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 837023794787135488,
#   'id_str': '837023794787135488',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 397,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 01 14:13:15 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/smIXbl2DQR',
#       'expanded_url': 'https://twitter.com/MrEdTrain/status/836942413096697857/photo/1',
#       'id': 836942406503264256,
#       'id_str': '836942406503264256',
#       'indices': [102, 125],
#       'media_url': 'http://pbs.twimg.com/media/C51qrzUWcAAEPis.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C51qrzUWcAAEPis.jpg',
#       'sizes': {'large': {'h': 1024, 'resize': 'fit', 'w': 600},
#        'medium': {'h': 1024, 'resize': 'fit', 'w': 600},
#        'small': {'h': 680, 'resize': 'fit', 'w': 398},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/smIXbl2DQR'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 818876014390603776,
#       'id_str': '818876014390603776',
#       'indices': [77, 84],
#       'name': 'Melania Trump',
#       'screen_name': 'FLOTUS'},
#      {'id': 25073877,
#       'id_str': '25073877',
#       'indices': [85, 101],
#       'name': 'Donald J. Trump',
#       'screen_name': 'realDonaldTrump'}]},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/smIXbl2DQR',
#       'expanded_url': 'https://twitter.com/MrEdTrain/status/836942413096697857/photo/1',
#       'id': 836942406503264256,
#       'id_str': '836942406503264256',
#       'indices': [102, 125],
#       'media_url': 'http://pbs.twimg.com/media/C51qrzUWcAAEPis.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C51qrzUWcAAEPis.jpg',
#       'sizes': {'large': {'h': 1024, 'resize': 'fit', 'w': 600},
#        'medium': {'h': 1024, 'resize': 'fit', 'w': 600},
#        'small': {'h': 680, 'resize': 'fit', 'w': 398},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/smIXbl2DQR'}]},
#    'favorite_count': 768,
#    'favorited': False,
#    'geo': None,
#    'id': 836942413096697857,
#    'id_str': '836942413096697857',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 397,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'Stunning as usual &amp; proud of her husband &amp; Commander &amp;  Chief 🇺🇸 @FLOTUS @realDonaldTrump https://t.co/smIXbl2DQR',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Dec 03 01:57:20 +0000 2014',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Born down on 8th street,brought up on L Street, Southie will always be my hometown! Cath,Pro Israel ,Life,2A,USMCR,Love God,Family,Country, Humor always ! TRUMP',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'trump.com',
#         'expanded_url': 'http://www.trump.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/11hHsShwB3'}]}},
#     'favourites_count': 192862,
#     'follow_request_sent': None,
#     'followers_count': 46155,
#     'following': None,
#     'friends_count': 38474,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 2903166449,
#     'id_str': '2903166449',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 648,
#     'location': 'Quincy, MA ',
#     'name': '☘️EddieMAGATrump🇺🇸',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2903166449/1469572199',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/818239452002848768/ZN6N_KZI_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/818239452002848768/ZN6N_KZI_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'MrEdTrain',
#     'statuses_count': 186623,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/11hHsShwB3',
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @MrEdTrain: Stunning as usual &amp; proud of her husband &amp; Commander &amp;  Chief 🇺🇸 @FLOTUS @realDonaldTrump https://t.co/smIXbl2DQR',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Oct 17 21:15:02 +0000 2013',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Loyal Trump Supporter & Warrior / MAGA / Blue Lives Matter / Never Surrendering To Left / Thinking Hyper- Dimensionally / Taking Nothing For Granted / Patriot',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 1313,
#    'follow_request_sent': None,
#    'followers_count': 3231,
#    'following': None,
#    'friends_count': 3516,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1967608022,
#    'id_str': '1967608022',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 225,
#    'location': 'Abandoned In Port Orange, Fla',
#    'name': 'Dawgy65',
#    'notifications': None,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/633285149568856064/SiK1nK6W.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/633285149568856064/SiK1nK6W.jpg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1967608022/1487268949',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/806561084656132096/LkE1bS_R_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/806561084656132096/LkE1bS_R_normal.jpg',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'woofeous',
#    'statuses_count': 81766,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 19:36:38 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 69751371,
#      'id_str': '69751371',
#      'indices': [3, 18],
#      'name': 'Nikki & Noelle',
#      'screen_name': 'thezachkotwins'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 837023793889624064,
#   'id_str': '837023793889624064',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 11,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 01 18:11:55 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'slate.com/blogs/the_slat…',
#       'expanded_url': 'http://www.slate.com/blogs/the_slatest/2017/03/01/the_media_are_suddenly_declaring_trump_presidential_that_s_absurd.html',
#       'indices': [117, 140],
#       'url': 'https://t.co/yarGCM2QMX'}],
#     'user_mentions': []},
#    'favorite_count': 19,
#    'favorited': False,
#    'geo': None,
#    'id': 837002473516773376,
#    'id_str': '837002473516773376',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 11,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': '💯\nReading teleprompter=less unhinged but he still vilified immigrants,lied,exploited war widow,pettily chided Dems...https://t.co/yarGCM2QMX',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Aug 29 01:30:48 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Music is our life, u dig?',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 35062,
#     'follow_request_sent': None,
#     'followers_count': 625,
#     'following': None,
#     'friends_count': 1005,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 69751371,
#     'id_str': '69751371',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 17,
#     'location': 'Boston, MA',
#     'name': 'Nikki & Noelle',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/187070149/nvseasonlights.br.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/187070149/nvseasonlights.br.jpg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/69751371/1483823309',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/817840349716561922/Qxbl6vJO_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/817840349716561922/Qxbl6vJO_normal.jpg',
#     'profile_link_color': 'EB0CB7',
#     'profile_sidebar_border_color': 'B38807',
#     'profile_sidebar_fill_color': '99087C',
#     'profile_text_color': '2E2B2E',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'thezachkotwins',
#     'statuses_count': 11843,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @thezachkotwins: 💯\nReading teleprompter=less unhinged but he still vilified immigrants,lied,exploited war widow,pettily chided Dems...ht…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Dec 18 17:25:25 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 11608,
#    'follow_request_sent': None,
#    'followers_count': 431,
#    'following': None,
#    'friends_count': 461,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 4526739573,
#    'id_str': '4526739573',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 42,
#    'location': '',
#    'name': 'Brenda Lalonde',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4526739573/1450459727',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/836289583977484288/G6fACrIC_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/836289583977484288/G6fACrIC_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'BrendaLalonde7',
#    'statuses_count': 23731,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 19:36:38 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 42546969,
#      'id_str': '42546969',
#      'indices': [3, 17],
#      'name': 'Pete Blackburn',
#      'screen_name': 'PeteBlackburn'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 837023793860214784,
#   'id_str': '837023793860214784',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 63,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 01 19:33:49 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 158,
#    'favorited': False,
#    'geo': None,
#    'id': 837023084976680960,
#    'id_str': '837023084976680960',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 63,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': 'The Vegas Golden Knights are officially an NHL team, so congrats to the Avalanche for not being only team to finish with 0 points this year',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue May 26 02:42:46 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "Writer, @FOXSports. Sports & pop culture. Co-host of @Section10pod & @ListenToBrunch. It's not that serious. (IG/Snap: peteblackburn)",
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 13717,
#     'follow_request_sent': None,
#     'followers_count': 37308,
#     'following': None,
#     'friends_count': 895,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 42546969,
#     'id_str': '42546969',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 726,
#     'location': 'Boston',
#     'name': 'Pete Blackburn',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/665774970/d0b0dc98f8ba52f55bbcca17e1a8797e.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/665774970/d0b0dc98f8ba52f55bbcca17e1a8797e.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/42546969/1484229937',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/831331741344399360/P2mqjh-D_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/831331741344399360/P2mqjh-D_normal.jpg',
#     'profile_link_color': 'C91010',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '616161',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'PeteBlackburn',
#     'statuses_count': 83546,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -18000,
#     'verified': True}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @PeteBlackburn: The Vegas Golden Knights are officially an NHL team, so congrats to the Avalanche for not being only team to finish with…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Oct 14 18:31:42 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'do you like smash mouth',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'vine.co/v/Ov3AuPYw5d9',
#        'expanded_url': 'https://vine.co/v/Ov3AuPYw5d9',
#        'indices': [0, 23],
#        'url': 'https://t.co/vnb3K8NKCk'}]}},
#    'favourites_count': 45424,
#    'follow_request_sent': None,
#    'followers_count': 611,
#    'following': None,
#    'friends_count': 1828,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 390895487,
#    'id_str': '390895487',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 14,
#    'location': 'space',
#    'name': 'Evan',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000176848377/uRGpX6LS.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000176848377/uRGpX6LS.jpeg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/390895487/1479536097',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/809165446402494464/AO6dUtM__normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/809165446402494464/AO6dUtM__normal.jpg',
#    'profile_link_color': 'D02B55',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '99CC33',
#    'profile_text_color': '3E4415',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'evanmNJD',
#    'statuses_count': 24636,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/vnb3K8NKCk',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.063701, 42.358424], 'type': 'Point'},
#   'created_at': 'Wed Mar 01 19:36:38 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'bitly.com/WpDUWZ',
#      'expanded_url': 'http://bitly.com/WpDUWZ',
#      'indices': [70, 93],
#      'url': 'https://t.co/lnmGzMO9dM'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.358424, -71.063701], 'type': 'Point'},
#   'id': 837023793684090889,
#   'id_str': '837023793684090889',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Boston, MA',
#    'id': '67b98f17fdcf20be',
#    'name': 'Boston',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://legiscan.com/" rel="nofollow">eLobbyist</a>',
#   'text': 'H1616 [NEW] Improving the tax administrative laws of the Commonwealth https://t.co/lnmGzMO9dM',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Jan 14 05:33:57 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'National public service for legislative tracking and data API; both free and subscription offerings with advanced monitoring, research, and reporting tools.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'legiscan.com/MA',
#        'expanded_url': 'http://legiscan.com/MA',
#        'indices': [0, 22],
#        'url': 'http://t.co/sWIfpKXNEG'}]}},
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 114,
#    'following': None,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 104723605,
#    'id_str': '104723605',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 10,
#    'location': 'Massachusetts, USA',
#    'name': 'LegiScan MA',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/104723605/1416558833',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/535681437836394496/fK4yNXRB_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/535681437836394496/fK4yNXRB_normal.png',
#    'profile_link_color': '143F5B',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'LegiScanMA',
#    'statuses_count': 99786,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/sWIfpKXNEG',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 19:36:37 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 28527037,
#      'id_str': '28527037',
#      'indices': [0, 15],
#      'name': 'Joey Katzen',
#      'screen_name': 'reelbigbeagles'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 837023792136392705,
#   'id_str': '837023792136392705',
#   'in_reply_to_screen_name': 'reelbigbeagles',
#   'in_reply_to_status_id': 837009027691331585,
#   'in_reply_to_status_id_str': '837009027691331585',
#   'in_reply_to_user_id': 28527037,
#   'in_reply_to_user_id_str': '28527037',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for iΟS</a>',
#   'text': '@reelbigbeagles thanks!',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Nov 09 18:10:58 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Director of Data Science @iRobot. Mathematician from @MIT. Professional nerd by day, amateur nerd by night. https://t.co/r9YxFZmEIK',
#    'entities': {'description': {'urls': [{'display_url': 'keybase.io/angelabassa',
#        'expanded_url': 'http://keybase.io/angelabassa',
#        'indices': [108, 131],
#        'url': 'https://t.co/r9YxFZmEIK'}]},
#     'url': {'urls': [{'display_url': 'angelabassa.com',
#        'expanded_url': 'http://angelabassa.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/4HQNdCPdDT'}]}},
#    'favourites_count': 1751,
#    'follow_request_sent': None,
#    'followers_count': 3558,
#    'following': None,
#    'friends_count': 212,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 937467860,
#    'id_str': '937467860',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 229,
#    'location': 'Boston, MA',
#    'name': 'Angela Bassa',
#    'notifications': None,
#    'profile_background_color': 'F3F6F9',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/706936338/30d7b8ff5a6f22640745282f04085f8d.jpeg',
# ...
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/471651076/1454965329',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/820840026875408385/Vxj7SLzu_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/820840026875408385/Vxj7SLzu_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'timelessmike',
#    'statuses_count': 7707,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 19:36:36 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 15982292,
#      'id_str': '15982292',
#      'indices': [3, 11],
#      'name': 'Phil A. Buster',
#      'screen_name': 'onekade'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 837023786910289929,
#   'id_str': '837023786910289929',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 10,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 01 19:12:47 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 13,
#    'favorited': False,
#    'geo': None,
#    'id': 837017792385695744,
#    'id_str': '837017792385695744',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 10,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "Since the media is focused on the Trump Show lemme just run this by y'all real quick:",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Aug 25 15:04:15 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "against despair. for freedom. (views not always my employer's)",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'privacysos.org/blog',
#         'expanded_url': 'http://privacysos.org/blog',
#         'indices': [0, 23],
#         'url': 'https://t.co/UzzPvhMsLH'}]}},
#     'favourites_count': 56274,
#     'follow_request_sent': None,
#     'followers_count': 16582,
#     'following': None,
#     'friends_count': 2302,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 15982292,
#     'id_str': '15982292',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 772,
#     'location': 'Boston',
#     'name': 'Phil A. Buster',
#     'notifications': None,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/741755618/e7efc008b06faa7d1baeb04da754350f.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/741755618/e7efc008b06faa7d1baeb04da754350f.jpeg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15982292/1423952352',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/799292623307632640/w8u2JKYW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799292623307632640/w8u2JKYW_normal.jpg',
#     'profile_link_color': '2FC2EF',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '666666',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'onekade',
#     'statuses_count': 197402,
#     'time_zone': 'Quito',
#     'translator_type': 'none',
#     'url': 'https://t.co/UzzPvhMsLH',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'text': "RT @onekade: Since the media is focused on the Trump Show lemme just run this by y'all real quick:",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Mar 08 02:59:34 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'anti-fascist contagionista. multilingual afroboricua opinionista. shmears gossip, news, sports & tech w/humor & profanity',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'paypal.me/blogdiva',
#        'expanded_url': 'https://www.paypal.me/blogdiva',
#        'indices': [0, 23],
#        'url': 'https://t.co/7Uzj9JkVCd'}]}},
#    'favourites_count': 114342,
#    'follow_request_sent': None,
#    'followers_count': 28412,
#    'following': None,
#    'friends_count': 3694,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 820694,
#    'id_str': '820694',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 2199,
#    'location': 'my radical ideas infecting you',
#    'name': 'Liza Sabater 🇵🇷👸🏾',
#    'notifications': None,
#    'profile_background_color': 'FFD800',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/680423979232964610/D2hholl3.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/680423979232964610/D2hholl3.jpg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/820694/1485975584',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/815444934887084033/x2jgbp2Z_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/815444934887084033/x2jgbp2Z_normal.jpg',
#    'profile_link_color': '000000',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'E0FF92',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'blogdiva',
#    'statuses_count': 400907,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/7Uzj9JkVCd',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 19:36:36 +0000 2017',
#   'entities': {'hashtags': [{'indices': [74, 81], 'text': 'biases'},
#     {'indices': [82, 93], 'text': 'WorkTrends'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 22634164,
#      'id_str': '22634164',
#      'indices': [3, 15],
#      'name': 'Meghan M. Biro',
#      'screen_name': 'MeghanMBiro'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 837023785182060544,
#   'id_str': '837023785182060544',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 1,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 01 18:41:00 +0000 2017',
#    'entities': {'hashtags': [{'indices': [57, 64], 'text': 'biases'},
#      {'indices': [65, 76], 'text': 'WorkTrends'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 4,
#    'favorited': False,
#    'geo': None,
#    'id': 837009794959470592,
#    'id_str': '837009794959470592',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': 'A1: Assumptions are often wrong and based on preexisting #biases #WorkTrends',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Mar 03 15:26:39 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'CEO @TalentCulture | #WorkTrends Wed 1pmET | @Forbes @Entrepreneur @HuffingtonPost | #HR #Tech #Socbiz #Entrepreneur #FutureOfWork',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'talentculture.com',
#         'expanded_url': 'http://www.talentculture.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/MzzId6vQLu'}]}},
#     'favourites_count': 27328,
#     'follow_request_sent': None,
#     'followers_count': 135595,
#     'following': None,
#     'friends_count': 98175,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 22634164,
#     'id_str': '22634164',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 7036,
#     'location': 'Cambridge, MA ',
#     'name': 'Meghan M. Biro',
#     'notifications': None,
#     'profile_background_color': '009DDC',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/446495737635819521/XzyQ7TRg.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/446495737635819521/XzyQ7TRg.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/22634164/1359909277',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/745596307864174594/YKw8yQNt_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/745596307864174594/YKw8yQNt_normal.jpg',
#     'profile_link_color': '31A621',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DEF6FF',
#     'profile_text_color': '3D1957',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'MeghanMBiro',
#     'statuses_count': 218981,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/MzzId6vQLu',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @MeghanMBiro: A1: Assumptions are often wrong and based on preexisting #biases #WorkTrends',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Jun 26 22:47:51 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Tech writer and cl racer.. #iWork4HPE',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 171,
#    'follow_request_sent': None,
#    'followers_count': 315,
#    'following': None,
#    'friends_count': 1019,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 324606654,
#    'id_str': '324606654',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 36,
#    'location': 'India',
#    'name': 'Prasoon Suresh',
#    'notifications': None,
#    'profile_background_color': '59BEE4',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/670722409/7b1cad0896d22d75b85f5f86fc69b59f.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/670722409/7b1cad0896d22d75b85f5f86fc69b59f.jpeg',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2326330471/eYArKi20_normal',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2326330471/eYArKi20_normal',
#    'profile_link_color': '8FCAE0',
#    'profile_sidebar_border_color': '4BB7DF',
#    'profile_sidebar_fill_color': '191F22',
#    'profile_text_color': '4BB7DF',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'PrasoonSuresh',
#    'statuses_count': 1047,
#    'time_zone': 'Asia/Calcutta',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 19800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01
# 837022576501088257  {'created_at': 'Wed Mar 01 19:31:48 +0000 2017...
# 837022576220246022  {'created_at': 'Wed Mar 01 19:31:47 +0000 2017...
# 837022576123621376  {'created_at': 'Wed Mar 01 19:31:47 +0000 2017...
# 837022673700065280  {'created_at': 'Wed Mar 01 19:32:11 +0000 2017...
# 837022672668266496  {'created_at': 'Wed Mar 01 19:32:10 +0000 2017...
# 837022672659877891  {'created_at': 'Wed Mar 01 19:32:10 +0000 2017...
# ...                                                               ...
# 837023975846907916  {'created_at': 'Wed Mar 01 19:37:21 +0000 2017...
# 837023975741980672  {'created_at': 'Wed Mar 01 19:37:21 +0000 2017...
# 837023974139826186  {'created_at': 'Wed Mar 01 19:37:21 +0000 2017...
# 837023973095444481  {'created_at': 'Wed Mar 01 19:37:20 +0000 2017...
# 837023972579508224  {'created_at': 'Wed Mar 01 19:37:20 +0000 2017...
# 837023972067794944  {'created_at': 'Wed Mar 01 19:37:20 +0000 2017...
# 837023969744195585  {'created_at': 'Wed Mar 01 19:37:20 +0000 2017...
# 837023967961579520  {'created_at': 'Wed Mar 01 19:37:19 +0000 2017...
# 837023967630151680  {'created_at': 'Wed Mar 01 19:37:19 +0000 2017...
# 837023966237597696  {'created_at': 'Wed Mar 01 19:37:19 +0000 2017...
# 837023966069985286  {'created_at': 'Wed Mar 01 19:37:19 +0000 2017...
# 837023963805061124  {'created_at': 'Wed Mar 01 19:37:18 +0000 2017...
# 837023963108814848  {'created_at': 'Wed Mar 01 19:37:18 +0000 2017...
# 837023960281706496  {'created_at': 'Wed Mar 01 19:37:17 +0000 2017...
# 837023957303853056  {'created_at': 'Wed Mar 01 19:37:17 +0000 2017...
# 837024060395687940  {'created_at': 'Wed Mar 01 19:37:41 +0000 2017...
# 837024059514892288  {'created_at': 'Wed Mar 01 19:37:41 +0000 2017...
# 837024059493912583  {'created_at': 'Wed Mar 01 19:37:41 +0000 2017...
# 837024059351306242  {'created_at': 'Wed Mar 01 19:37:41 +0000 2017...
# 837024058151735303  {'created_at': 'Wed Mar 01 19:37:41 +0000 2017...
# 837024058038448128  {'created_at': 'Wed Mar 01 19:37:41 +0000 2017...
# 837024057191239683  {'created_at': 'Wed Mar 01 19:37:41 +0000 2017...
# 837024056499179525  {'created_at': 'Wed Mar 01 19:37:40 +0000 2017...
# 837024055966502920  {'created_at': 'Wed Mar 01 19:37:40 +0000 2017...
# 837024054833991680  {'created_at': 'Wed Mar 01 19:37:40 +0000 2017...
# 837024054703980548  {'created_at': 'Wed Mar 01 19:37:40 +0000 2017...
# 837024052095123456  {'created_at': 'Wed Mar 01 19:37:39 +0000 2017...
# 837024050572578820  {'created_at': 'Wed Mar 01 19:37:39 +0000 2017...
# 837024049087844354  {'created_at': 'Wed Mar 01 19:37:39 +0000 2017...
# 837024048253177863  {'created_at': 'Wed Mar 01 19:37:38 +0000 2017...
#
#                    data_point                            time
# 836939011939831810       none  Wed Mar 01 13:59:44 +0000 2017
# 835556119506477056       none  Sat Feb 25 18:24:37 +0000 2017
# 835129186964680706       none  Fri Feb 24 14:08:08 +0000 2017
# 837024058038448128       none  Wed Mar 01 19:37:41 +0000 2017
# 837024057191239683       none  Wed Mar 01 19:37:41 +0000 2017
# 837024056499179525       none  Wed Mar 01 19:37:40 +0000 2017
# 837024055966502920       none  Wed Mar 01 19:37:40 +0000 2017
# 837024054833991680       none  Wed Mar 01 19:37:40 +0000 2017
# 837024054703980548       none  Wed Mar 01 19:37:40 +0000 2017
# 837024052095123456       none  Wed Mar 01 19:37:39 +0000 2017
# 837024050572578820       none  Wed Mar 01 19:37:39 +0000 2017
# 837024049087844354       none  Wed Mar 01 19:37:39 +0000 2017
# 837024048253177863       none  Wed Mar 01 19:37:38 +0000 2017
#
# [117 rows x 9 columns]

# %% [markdown]
# ### 7. Summarize, Group, and Plot the Dataset
#
# Next let's summarize and group our data, and create some plots.
#
# **A** - First, group by the user location. This is not lat/lon, but rather the information the individual has input on their profile.
#
# When you give people the power to input their own location, you get an assortment of 'creative' responses!

# %%
df_tweets.dtypes
# Out:
# tweet_id      object
# lat           object
# lon           object
# content       object
# location      object
# user          object
# raw_source    object
# data_point    object
# time          object
# dtype: object

# %%
df_tweets['location'].unique()
# Out:
# array(['Carlisle, PA', 'Jonestown', 'Japan  Kagoshima city',
#        'Carlisle, Pa.', 'Pittsburgh, PA', 'Bellevue, WA', 'Raleigh, NC',
#        'Enola, PA', 'York,PA', 'Lewisberry, PA', '', 'Harrisburg, PA',
#        'York, PA', 'West York, PA', '대한민국',
#        'Harrisburg, Pennsylvania, USA', 'somewheretrynabegreat',
#        'Harrisburg,PA', 'Baltimore, MD', 'Middletown, PA'], dtype=object)

# %% [markdown]
# Now let's do some grouping and sorting. We are using Pandas to do our analysis, much like last week.

# %%
grouped_tweets = df_tweets.groupby('location')
count_tweets = grouped_tweets['location'].count()
df_count_tweets = count_tweets.to_frame()
df_count_tweets.columns = ['Count']
df_count_tweets.index.names = ['Location']
df_count_tweets.sort_index()
# Out:
#                        Count
# Location
# Bellevue, WA               1
# Carlisle, PA               4
# Carlisle, Pa.              1
# Enola, PA                  1
# Japan  Kagoshima city      1
# Jonestown                  2
# Pittsburgh, PA             1
# Raleigh, NC                1

# %% [markdown]
# Let's create a pie chart of these using matplotlib.

# %%
# Create a list of colors (from iWantHue)
colors = ["#d1d4ce","#282723","#76a44a","#565b55",
          "#cc54bc","#4bad89","#d84577","#4eacd7",
          "#cf4e33","#894ea8","#cf8c42","#d58cc9",
          "#737632","#9f4b75","#c36960"]

# Create a pie chart
plt.pie( df_count_tweets['Count'], labels=df_count_tweets.index.get_values(), shadow=False, colors=colors)

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# There are quite a few duplicates that we can clearly see, you will likely want to clean this data to rectify this.

# %% [markdown]
# **B** - Next, let's find how many actually have a location and put them on a scatterplot. To do this, we need to find first the rows where lat and long are not None, and then create the plot from just that subset of the data. Let's give it a go.

# %%
# Create a filter from df_tweets filtering only those that have values for lat and lon
df_tweets_with_location = df_tweets[df_tweets.lon.notnull() & df_tweets.lat.notnull()]
df_tweets_with_location
# Out:
# Empty DataFrame
# Columns: [tweet_id, lat, lon, content, location, user, raw_source, data_point, time]
# Index: []

# %%
# Use a scatter plot to make a quick visualization of the data points
# NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-1dff57db92fa> in <module>()
#       1 # Use a scatter plot to make a quick visualization of the data points
#       2 # NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
# ----> 3 plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
#       4 plt.show()
#
# //anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3433                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3434                          linewidths=linewidths, verts=verts,
# -> 3435                          edgecolors=edgecolors, data=data, **kwargs)
#    3436     finally:
#    3437         ax._hold = washold
#
# //anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# //anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3993         maskargs = x, y, s, c, colors, edgecolors, linewidths
#    3994         x, y, s, c, colors, edgecolors, linewidths =\
# -> 3995             cbook.delete_masked_points(*maskargs)
#    3996
#    3997         scales = s   # Renamed for readability below.
#
# //anaconda/lib/python3.6/site-packages/matplotlib/cbook.py in delete_masked_points(*args)
#    1834         return ()
#    1835     if (is_string_like(args[0]) or not iterable(args[0])):
# -> 1836         raise ValueError("First argument must be a sequence")
#    1837     nrecs = len(args[0])
#    1838     margs = []
#
# ValueError: First argument must be a sequence

# %% [markdown]
# ### 8. Clean the Data
#
# **Clean the Locations** - You saw above that we had a bunch of locations that were very similar. Here, we could use [replace](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.replace.html). For example, we could replace all the variations of **York, PA** with a singular string using something like the following:

# %%
# List of variations of York
variations_of_Carlisle = ['Carliste, PA','Carlisle, Pa.']
    #,'York, Pennsylvania','York, Pa','41 W Market Street York, Pa','york P.a. ','York, Pa.']

df_tweets['location'].replace(variations_of_Carlisle, 'Carlisle, PA')
# Out:
# 836939011939831810             Carlisle, PA
# 835556119506477056                Jonestown
# 835129186964680706                Jonestown
# 834953234577940480    Japan  Kagoshima city
# 834928453166190592             Carlisle, PA
# 834825970590818305             Carlisle, PA
# 834792393647984640           Pittsburgh, PA
# 834776681269194753             Bellevue, WA
# 834775331953373184              Raleigh, NC
# 834775231575109632             Carlisle, PA
# 834256209054146564                Enola, PA
# 833506764691738625             Carlisle, PA
# Name: location, dtype: object

# %% [markdown]
# **Remove Duplicates** - Make sure that we don't get tweets plotted more than once. How would you make sure to only plot unique tweets? We can maybe use [drop_duplicates](http://chrisalbon.com/python/pandas_delete_duplicates.html)

# %% [markdown]
# ### 9. Exporting your Data to CSV
#
# Exporting your dataset is easy, you can use **to_csv()**. This [Stack Exchange](http://stackoverflow.com/questions/16923281/pandas-writing-dataframe-to-csv-file) page will help you.

# %%
df_tweets.to_csv('twitter_data_MIT.csv', sep=',', encoding='utf-8')

# %% [markdown]
# ### Problem Set 3 - Extend What You Have Learned
#
# Now that you know how to scrape data from Twitter, let's extend the exercise a little so you can show us what you know. This time you will set up the scraper to get data around MIT and scrape data for 20 minutes. Then you will visualize it with  and visualize. Think about what you would need to change to do that.
#
# Once you have the new JSON file of Boston tweets you should a pie chart and scatterplot of your collected tweets. When you are creating your dataset, you should get at least two different attributes returned by the Twitter API (we got many of them above, so base it off of that example). Atleast one of them should be the tweet id. Make sure you remove and duplicate tweets (if any). Expanding on the above, then save the data to a CSV.
#
# Make sure you get your own Twitter Key.
#
# #### Deliverables
#
# **1** - Using the Twitter REST API, collect Tweets from Boston for 30 min. Note how you set the time in the above example (in the **run_all()** function), it was in seconds. How would you do that here?
#
# **2** - Create a Pie Chart showing a summary of tweets by user location. Please clean up the data so that multiple variations of the same location name are replaced with one variation.
#
# **3** - Create a Scatterplot showing all of the tweets that had a latitude and longitude.
#
# **4** - Pick a search term, such as *Trump* or *#Trump* and collect 15 minutes of tweets on it. Use the same lat/lon for Boston as you used above.
#
# **5** - Export the entirety of your scraped Twitter datasets (one with a search term, one without) to two CSV files. We will be checking this CSV file for duplicates. So clean your file.
#
# ### What to Give Us on Stellar
#
# 1 - Create a new Jupyter notebook that contains your scraper code. You can copy much of this one, but customize it. Submit the new Jupyter notebook, which includes your pie chart and scatterplot.
#
# 2 - Your final CSV files.
